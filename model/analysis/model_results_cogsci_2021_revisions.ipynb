# %%
import os
import sys
import urllib, io
os.getcwd()
sys.path.append("..")
sys.path.append("../utils")
sys.path.append("../analysis/utils")
import glob

import numpy as np
import scipy.stats as stats
import pandas as pd

import pymongo as pm
from collections import Counter
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

# %%
## directory & file hierarchy
proj_dir = os.path.abspath('..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir =  os.path.abspath('.')
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
json_dir = os.path.join(results_dir,'json')
exp_dir = os.path.abspath(os.path.join(proj_dir,'behavioral_experiments'))
png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %% [markdown]
# ### Import model results

# %%
model_output_dir = os.path.abspath('../output/49ppts')

all_files = glob.glob(model_output_dir + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df_model = pd.concat(li, axis=0, ignore_index=True).sort_values(['ppt','iteration','chainNum','alpha','beta','trialNum'])

# # swap mislabeled columns
# intendedSequence = df_model['speakerUtterance'].copy()
# speakerUtterance = df_model['intendedSequence'].copy()
# df_model['speakerUtterance'] = speakerUtterance
# df_model['intendedSequence'] = intendedSequence

# %% [markdown]
# - iterationName: 0 to 99
# - chainNum: index for parameter pair
# - alpha:
# - beta:

# %%
df_model
# Out:
#        chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 37200         0    1          0      1   0.0         0      True
# 37201         0    1          0      1   0.0         1      True
# 37202         0    1          0      1   0.0         2     False
# 37203         0    1          0      1   0.0         3      True
# 37204         0    1          0      1   0.0         4      True
# 37205         0    1          0      1   0.0         5      True
# 37206         0    1          0      1   0.0         6     False
# 37207         0    1          0      1   0.0         7      True
# 37208         0    1          0      1   0.0         8      True
# 37209         0    1          0      1   0.0         9      True
# 37210         0    1          0      1   0.0        10      True
# 37211         0    1          0      1   0.0        11      True
# 30528        49    1          0      1   0.1         0      True
# 30529        49    1          0      1   0.1         1      True
# 30530        49    1          0      1   0.1         2      True
# 30531        49    1          0      1   0.1         3      True
# 30532        49    1          0      1   0.1         4      True
# 30533        49    1          0      1   0.1         5     False
# 30534        49    1          0      1   0.1         6      True
# 30535        49    1          0      1   0.1         7      True
# 30536        49    1          0      1   0.1         8      True
# 30537        49    1          0      1   0.1         9     False
# 30538        49    1          0      1   0.1        10      True
# 30539        49    1          0      1   0.1        11      True
# 23472        98    1          0      1   0.2         0      True
# 23473        98    1          0      1   0.2         1      True
# 23474        98    1          0      1   0.2         2      True
# 23475        98    1          0      1   0.2         3      True
# 23476        98    1          0      1   0.2         4      True
# 23477        98    1          0      1   0.2         5      True
# ...         ...  ...        ...    ...   ...       ...       ...
# 42186      2057   49          1     64   0.8         6     False
# 42187      2057   49          1     64   0.8         7     False
# 42188      2057   49          1     64   0.8         8     False
# 42189      2057   49          1     64   0.8         9     False
# 42190      2057   49          1     64   0.8        10     False
# 42191      2057   49          1     64   0.8        11     False
# 6156       2106   49          1     64   0.9         0      True
# 6157       2106   49          1     64   0.9         1      True
# 6158       2106   49          1     64   0.9         2      True
# 6159       2106   49          1     64   0.9         3      True
# 6160       2106   49          1     64   0.9         4      True
# 6161       2106   49          1     64   0.9         5     False
# 6162       2106   49          1     64   0.9         6     False
# 6163       2106   49          1     64   0.9         7     False
# 6164       2106   49          1     64   0.9         8     False
# 6165       2106   49          1     64   0.9         9     False
# 6166       2106   49          1     64   0.9        10     False
# 6167       2106   49          1     64   0.9        11     False
# 35076      2155   49          1     64   1.0         0      True
# 35077      2155   49          1     64   1.0         1      True
# 35078      2155   49          1     64   1.0         2      True
# 35079      2155   49          1     64   1.0         3      True
# 35080      2155   49          1     64   1.0         4     False
# 35081      2155   49          1     64   1.0         5     False
# 35082      2155   49          1     64   1.0         6      True
# 35083      2155   49          1     64   1.0         7     False
# 35084      2155   49          1     64   1.0         8     False
# 35085      2155   49          1     64   1.0         9     False
# 35086      2155   49          1     64   1.0        10     False
# 35087      2155   49          1     64   1.0        11     False
#
#        descriptionLength                         intendedSequence  \
# 37200                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 37201                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 37202                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 37203                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 37204                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 37205                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37206                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37207                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37208                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37209                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37210                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37211                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30528                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 30529                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 30530                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 30531                 14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 30532                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 30533                  9          v r_6 v l_5 h r_4 h r_9 chunk_L
# 30534                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30535                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30536                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30537                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30538                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30539                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 23472                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 23473                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 23474                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 23475                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 23476                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 23477                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# ...                  ...                                      ...
# 42186                  3                     chunk_Pi r_9 chunk_L
# 42187                  3                     chunk_Pi r_9 chunk_L
# 42188                  3                     chunk_Pi r_9 chunk_L
# 42189                  3                     chunk_Pi r_9 chunk_L
# 42190                  3                     chunk_Pi r_9 chunk_L
# 42191                  3                     chunk_Pi r_9 chunk_L
# 6156                  13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 6157                  14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 6158                  14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 6159                  11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 6160                   5              chunk_8b r_9 h l_4 chunk_Pi
# 6161                   3                     chunk_Pi r_9 chunk_L
# 6162                   3                     chunk_Pi r_9 chunk_L
# 6163                   3                     chunk_Pi r_9 chunk_L
# 6164                   3                     chunk_Pi r_9 chunk_L
# 6165                   3                     chunk_Pi r_9 chunk_L
# 6166                   3                     chunk_Pi r_9 chunk_L
# 6167                   3                     chunk_Pi r_9 chunk_L
# 35076                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35077                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35078                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35079                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35080                  5              chunk_8b r_9 h l_4 chunk_Pi
# 35081                  3                     chunk_Pi r_9 chunk_L
# 35082                  3                     chunk_Pi r_9 chunk_L
# 35083                  3                     chunk_Pi r_9 chunk_L
# 35084                  3                     chunk_Pi r_9 chunk_L
# 35085                  3                     chunk_Pi r_9 chunk_L
# 35086                  3                     chunk_Pi r_9 chunk_L
# 35087                  3                     chunk_Pi r_9 chunk_L
#
#                                         speakerUtterance  \
# 37200  place a horizontal block.~~~move to the left b...
# 37201  place a horizontal block.~~~move to the left b...
# 37202  place a horizontal block.~~~move to the left b...
# 37203  place a vertical block.~~~move to the right by...
# 37204  place a horizontal block.~~~move to the left b...
# 37205  place a vertical block.~~~move to the right by...
# 37206  place a vertical block.~~~move to the right by...
# 37207  place a vertical block.~~~move to the right by...
# 37208  place a vertical block.~~~move to the right by...
# 37209  place a vertical block.~~~move to the right by...
# 37210  place a vertical block.~~~move to the right by...
# 37211  place a vertical block.~~~move to the right by...
# 30528  place a horizontal block.~~~move to the left b...
# 30529  place a horizontal block.~~~move to the left b...
# 30530  place a horizontal block.~~~move to the left b...
# 30531  place a vertical block.~~~move to the right by...
# 30532  place a horizontal block.~~~move to the left b...
# 30533  place a vertical block.~~~move to the right by...
# 30534  place a vertical block.~~~move to the right by...
# 30535  place a vertical block.~~~move to the right by...
# 30536  place a vertical block.~~~move to the right by...
# 30537  place a vertical block.~~~move to the right by...
# 30538  place a vertical block.~~~move to the right by...
# 30539  place a vertical block.~~~move to the right by...
# 23472  place a horizontal block.~~~move to the left b...
# 23473  place a horizontal block.~~~move to the left b...
# 23474  place a horizontal block.~~~move to the left b...
# 23475  place a vertical block.~~~move to the right by...
# 23476  place a horizontal block.~~~move to the left b...
# 23477  place a vertical block.~~~move to the right by...
# ...                                                  ...
# 42186             blarp~~~move to the right by 9~~~blarp
# 42187             blarp~~~move to the right by 9~~~blarp
# 42188             blarp~~~move to the right by 9~~~blarp
# 42189             blarp~~~move to the right by 9~~~blarp
# 42190             blarp~~~move to the right by 9~~~blarp
# 42191             blarp~~~move to the right by 9~~~blarp
# 6156   place a horizontal block.~~~move to the left b...
# 6157   place a horizontal block.~~~move to the left b...
# 6158   place a horizontal block.~~~move to the left b...
# 6159   place a vertical block.~~~move to the right by...
# 6160   blarp~~~move to the right by 9~~~place a horiz...
# 6161                blab~~~move to the right by 9~~~blah
# 6162                blah~~~move to the right by 9~~~blab
# 6163                blab~~~move to the right by 9~~~blah
# 6164                blah~~~move to the right by 9~~~blab
# 6165                blah~~~move to the right by 9~~~blah
# 6166                blah~~~move to the right by 9~~~blab
# 6167                blah~~~move to the right by 9~~~blab
# 35076  place a horizontal block.~~~move to the left b...
# 35077  place a horizontal block.~~~move to the left b...
# 35078  place a horizontal block.~~~move to the left b...
# 35079  place a vertical block.~~~move to the right by...
# 35080  blarp~~~move to the right by 9~~~place a horiz...
# 35081             blarp~~~move to the right by 9~~~bloop
# 35082             bloop~~~move to the right by 9~~~bleep
# 35083               blah~~~move to the right by 9~~~blab
# 35084             blarp~~~move to the right by 9~~~bloop
# 35085              blah~~~move to the right by 9~~~bloop
# 35086              bleep~~~move to the right by 9~~~blab
# 35087              bleep~~~move to the right by 9~~~blab
#
#                                     listenerResponse
# 37200        h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 37201           h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 37202     h l_1 v v r_1 l_10 r_6 v r_6 v l_5 h r_4 h
# 37203         v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 37204           h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 37205        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37206  v r_6 v l_5 chunk_C r_4 h r_9 h l_4 h l_1 v v
# 37207        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37208        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37209        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37210        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37211        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30528        h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 30529           h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 30530        h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 30531        v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 30532           h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 30533                v r_6 v l_5 h r_4 h r_9 chunk_8
# 30534        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30535        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30536        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30537      v r_6 v l_5 h r_4 r_7 r_9 h l_4 h l_1 v v
# 30538        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30539        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 23472        h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 23473           h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 23474        h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 23475         v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 23476           h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 23477        v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# ...                                              ...
# 42186                           chunk_8 r_9 chunk_8b
# 42187                           chunk_L r_9 chunk_Pi
# 42188                           chunk_Pi r_9 chunk_C
# 42189                           chunk_8 r_9 chunk_Pi
# 42190                            chunk_L r_9 chunk_8
# 42191                          chunk_8b r_9 chunk_Pi
# 6156            h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 6157         h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 6158         h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 6159          v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 6160                     chunk_8b r_9 h l_4 chunk_Pi
# 6161                           chunk_8b r_9 chunk_Pi
# 6162                            chunk_8b r_9 chunk_C
# 6163                            chunk_8 r_9 chunk_Pi
# 6164                            chunk_L r_9 chunk_8b
# 6165                           chunk_8b r_9 chunk_Pi
# 6166                            chunk_8b r_9 chunk_L
# 6167                            chunk_8b r_9 chunk_8
# 35076           h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35077        h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35078        h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35079         v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35080                    chunk_Pi r_9 h l_4 chunk_8b
# 35081                           chunk_Pi r_9 chunk_8
# 35082                           chunk_Pi r_9 chunk_L
# 35083                           chunk_C r_9 chunk_8b
# 35084                            chunk_C r_9 chunk_8
# 35085                           chunk_8b r_9 chunk_L
# 35086                            chunk_8 r_9 chunk_L
# 35087                            chunk_C r_9 chunk_L
#
# [51744 rows x 11 columns]

# %%
def get_intended_refs(intendedSequenceList):
    return[exp for exp in intendedSequenceList if ((not exp.startswith('r_')) & ( not exp.startswith('l_')))]

# %%
# preprocessing

df_model['intendedSequenceList'] = df_model['intendedSequence'].apply(lambda string: string.split(' '))
df_model['listenerResponseList'] = df_model['listenerResponse'].apply(lambda string: string.split(' '))
df_model['speakerUtteranceList'] = df_model['speakerUtterance'].apply(lambda string: string.split('~~~'))

df_model['speakerUtteranceWords'] = df_model['speakerUtterance'].apply(lambda string: string.split('~~~'))
df_model['intended_refs'] = df_model['intendedSequenceList'].apply(get_intended_refs)

#checks
assert np.all(df_model['intendedSequenceList'].apply(len) == df_model['descriptionLength'])
assert np.all(df_model['speakerUtteranceList'].apply(len) == df_model['descriptionLength'])

# %%
df_model['repetition'] = np.floor((df_model['trialNum']/3))+1

# %%
intended_abstraction_levels = {
    'v': 'block',
    'h': 'block',
    'chunk_L': 'tower',
    'chunk_Pi': 'tower',
    'chunk_C': 'tower',
    'chunk_8': 'subtower',
    'chunk_8b': 'subtower',
    'chunk_9': 'subtower'
}

# %%
def abstraction_level(intended_ref):
    assert intended_ref in intended_abstraction_levels.keys()
    if intended_ref in intended_abstraction_levels.keys():
        return intended_abstraction_levels[intended_ref]
    else:
        print(intended_ref)
        return 'UNKNOWN'

# %%
df_model['intended_abstraction_level'] = \
        df_model['intended_refs'].apply(lambda intended_refs: [abstraction_level(ref) for ref in intended_refs])

# %%
df_model['intended_blocks'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['block'])
df_model['intended_subtowers'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['subtower'])
df_model['intended_towers'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['tower'])

# %%
df_model
# Out:
#        chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 37200         0    1          0      1   0.0         0      True
# 37201         0    1          0      1   0.0         1      True
# 37202         0    1          0      1   0.0         2     False
# 37203         0    1          0      1   0.0         3      True
# 37204         0    1          0      1   0.0         4      True
# 37205         0    1          0      1   0.0         5      True
# 37206         0    1          0      1   0.0         6     False
# 37207         0    1          0      1   0.0         7      True
# 37208         0    1          0      1   0.0         8      True
# 37209         0    1          0      1   0.0         9      True
# 37210         0    1          0      1   0.0        10      True
# 37211         0    1          0      1   0.0        11      True
# 30528        49    1          0      1   0.1         0      True
# 30529        49    1          0      1   0.1         1      True
# 30530        49    1          0      1   0.1         2      True
# 30531        49    1          0      1   0.1         3      True
# 30532        49    1          0      1   0.1         4      True
# 30533        49    1          0      1   0.1         5     False
# 30534        49    1          0      1   0.1         6      True
# 30535        49    1          0      1   0.1         7      True
# 30536        49    1          0      1   0.1         8      True
# 30537        49    1          0      1   0.1         9     False
# 30538        49    1          0      1   0.1        10      True
# 30539        49    1          0      1   0.1        11      True
# 23472        98    1          0      1   0.2         0      True
# 23473        98    1          0      1   0.2         1      True
# 23474        98    1          0      1   0.2         2      True
# 23475        98    1          0      1   0.2         3      True
# 23476        98    1          0      1   0.2         4      True
# 23477        98    1          0      1   0.2         5      True
# ...         ...  ...        ...    ...   ...       ...       ...
# 42186      2057   49          1     64   0.8         6     False
# 42187      2057   49          1     64   0.8         7     False
# 42188      2057   49          1     64   0.8         8     False
# 42189      2057   49          1     64   0.8         9     False
# 42190      2057   49          1     64   0.8        10     False
# 42191      2057   49          1     64   0.8        11     False
# 6156       2106   49          1     64   0.9         0      True
# 6157       2106   49          1     64   0.9         1      True
# 6158       2106   49          1     64   0.9         2      True
# 6159       2106   49          1     64   0.9         3      True
# 6160       2106   49          1     64   0.9         4      True
# 6161       2106   49          1     64   0.9         5     False
# 6162       2106   49          1     64   0.9         6     False
# 6163       2106   49          1     64   0.9         7     False
# 6164       2106   49          1     64   0.9         8     False
# 6165       2106   49          1     64   0.9         9     False
# 6166       2106   49          1     64   0.9        10     False
# 6167       2106   49          1     64   0.9        11     False
# 35076      2155   49          1     64   1.0         0      True
# 35077      2155   49          1     64   1.0         1      True
# 35078      2155   49          1     64   1.0         2      True
# 35079      2155   49          1     64   1.0         3      True
# 35080      2155   49          1     64   1.0         4     False
# 35081      2155   49          1     64   1.0         5     False
# 35082      2155   49          1     64   1.0         6      True
# 35083      2155   49          1     64   1.0         7     False
# 35084      2155   49          1     64   1.0         8     False
# 35085      2155   49          1     64   1.0         9     False
# 35086      2155   49          1     64   1.0        10     False
# 35087      2155   49          1     64   1.0        11     False
#
#        descriptionLength                         intendedSequence  \
# 37200                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 37201                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 37202                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 37203                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 37204                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 37205                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37206                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37207                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37208                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37209                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37210                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 37211                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30528                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 30529                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 30530                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 30531                 14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 30532                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 30533                  9          v r_6 v l_5 h r_4 h r_9 chunk_L
# 30534                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30535                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30536                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30537                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30538                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 30539                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 23472                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 23473                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 23474                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 23475                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 23476                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 23477                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# ...                  ...                                      ...
# 42186                  3                     chunk_Pi r_9 chunk_L
# 42187                  3                     chunk_Pi r_9 chunk_L
# 42188                  3                     chunk_Pi r_9 chunk_L
# 42189                  3                     chunk_Pi r_9 chunk_L
# 42190                  3                     chunk_Pi r_9 chunk_L
# 42191                  3                     chunk_Pi r_9 chunk_L
# 6156                  13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 6157                  14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 6158                  14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 6159                  11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 6160                   5              chunk_8b r_9 h l_4 chunk_Pi
# 6161                   3                     chunk_Pi r_9 chunk_L
# 6162                   3                     chunk_Pi r_9 chunk_L
# 6163                   3                     chunk_Pi r_9 chunk_L
# 6164                   3                     chunk_Pi r_9 chunk_L
# 6165                   3                     chunk_Pi r_9 chunk_L
# 6166                   3                     chunk_Pi r_9 chunk_L
# 6167                   3                     chunk_Pi r_9 chunk_L
# 35076                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35077                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35078                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35079                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35080                  5              chunk_8b r_9 h l_4 chunk_Pi
# 35081                  3                     chunk_Pi r_9 chunk_L
# 35082                  3                     chunk_Pi r_9 chunk_L
# 35083                  3                     chunk_Pi r_9 chunk_L
# 35084                  3                     chunk_Pi r_9 chunk_L
# 35085                  3                     chunk_Pi r_9 chunk_L
# 35086                  3                     chunk_Pi r_9 chunk_L
# 35087                  3                     chunk_Pi r_9 chunk_L
#
#                                         speakerUtterance  ...  \
# 37200  place a horizontal block.~~~move to the left b...  ...
# 37201  place a horizontal block.~~~move to the left b...  ...
# 37202  place a horizontal block.~~~move to the left b...  ...
# 37203  place a vertical block.~~~move to the right by...  ...
# 37204  place a horizontal block.~~~move to the left b...  ...
# 37205  place a vertical block.~~~move to the right by...  ...
# 37206  place a vertical block.~~~move to the right by...  ...
# 37207  place a vertical block.~~~move to the right by...  ...
# 37208  place a vertical block.~~~move to the right by...  ...
# 37209  place a vertical block.~~~move to the right by...  ...
# 37210  place a vertical block.~~~move to the right by...  ...
# 37211  place a vertical block.~~~move to the right by...  ...
# 30528  place a horizontal block.~~~move to the left b...  ...
# 30529  place a horizontal block.~~~move to the left b...  ...
# 30530  place a horizontal block.~~~move to the left b...  ...
# 30531  place a vertical block.~~~move to the right by...  ...
# 30532  place a horizontal block.~~~move to the left b...  ...
# 30533  place a vertical block.~~~move to the right by...  ...
# 30534  place a vertical block.~~~move to the right by...  ...
# 30535  place a vertical block.~~~move to the right by...  ...
# 30536  place a vertical block.~~~move to the right by...  ...
# 30537  place a vertical block.~~~move to the right by...  ...
# 30538  place a vertical block.~~~move to the right by...  ...
# 30539  place a vertical block.~~~move to the right by...  ...
# 23472  place a horizontal block.~~~move to the left b...  ...
# 23473  place a horizontal block.~~~move to the left b...  ...
# 23474  place a horizontal block.~~~move to the left b...  ...
# 23475  place a vertical block.~~~move to the right by...  ...
# 23476  place a horizontal block.~~~move to the left b...  ...
# 23477  place a vertical block.~~~move to the right by...  ...
# ...                                                  ...  ...
# 42186             blarp~~~move to the right by 9~~~blarp  ...
# 42187             blarp~~~move to the right by 9~~~blarp  ...
# 42188             blarp~~~move to the right by 9~~~blarp  ...
# 42189             blarp~~~move to the right by 9~~~blarp  ...
# 42190             blarp~~~move to the right by 9~~~blarp  ...
# 42191             blarp~~~move to the right by 9~~~blarp  ...
# 6156   place a horizontal block.~~~move to the left b...  ...
# 6157   place a horizontal block.~~~move to the left b...  ...
# 6158   place a horizontal block.~~~move to the left b...  ...
# 6159   place a vertical block.~~~move to the right by...  ...
# 6160   blarp~~~move to the right by 9~~~place a horiz...  ...
# 6161                blab~~~move to the right by 9~~~blah  ...
# 6162                blah~~~move to the right by 9~~~blab  ...
# 6163                blab~~~move to the right by 9~~~blah  ...
# 6164                blah~~~move to the right by 9~~~blab  ...
# 6165                blah~~~move to the right by 9~~~blah  ...
# 6166                blah~~~move to the right by 9~~~blab  ...
# 6167                blah~~~move to the right by 9~~~blab  ...
# 35076  place a horizontal block.~~~move to the left b...  ...
# 35077  place a horizontal block.~~~move to the left b...  ...
# 35078  place a horizontal block.~~~move to the left b...  ...
# 35079  place a vertical block.~~~move to the right by...  ...
# 35080  blarp~~~move to the right by 9~~~place a horiz...  ...
# 35081             blarp~~~move to the right by 9~~~bloop  ...
# 35082             bloop~~~move to the right by 9~~~bleep  ...
# 35083               blah~~~move to the right by 9~~~blab  ...
# 35084             blarp~~~move to the right by 9~~~bloop  ...
# 35085              blah~~~move to the right by 9~~~bloop  ...
# 35086              bleep~~~move to the right by 9~~~blab  ...
# 35087              bleep~~~move to the right by 9~~~blab  ...
#
#                                     intendedSequenceList  \
# 37200  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 37201  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 37202  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 37203  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 37204  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 37205  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37206  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37207  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37208  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37209  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37210  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37211  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30528  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 30529  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 30530  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 30531  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 30532  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 30533          [v, r_6, v, l_5, h, r_4, h, r_9, chunk_L]
# 30534  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30535  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30536  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30537  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30538  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30539  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 23472  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 23473  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 23474  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 23475  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 23476  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 23477  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# ...                                                  ...
# 42186                           [chunk_Pi, r_9, chunk_L]
# 42187                           [chunk_Pi, r_9, chunk_L]
# 42188                           [chunk_Pi, r_9, chunk_L]
# 42189                           [chunk_Pi, r_9, chunk_L]
# 42190                           [chunk_Pi, r_9, chunk_L]
# 42191                           [chunk_Pi, r_9, chunk_L]
# 6156   [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 6157   [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 6158   [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 6159   [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 6160                   [chunk_8b, r_9, h, l_4, chunk_Pi]
# 6161                            [chunk_Pi, r_9, chunk_L]
# 6162                            [chunk_Pi, r_9, chunk_L]
# 6163                            [chunk_Pi, r_9, chunk_L]
# 6164                            [chunk_Pi, r_9, chunk_L]
# 6165                            [chunk_Pi, r_9, chunk_L]
# 6166                            [chunk_Pi, r_9, chunk_L]
# 6167                            [chunk_Pi, r_9, chunk_L]
# 35076  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35077  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35078  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35079  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 35080                  [chunk_8b, r_9, h, l_4, chunk_Pi]
# 35081                           [chunk_Pi, r_9, chunk_L]
# 35082                           [chunk_Pi, r_9, chunk_L]
# 35083                           [chunk_Pi, r_9, chunk_L]
# 35084                           [chunk_Pi, r_9, chunk_L]
# 35085                           [chunk_Pi, r_9, chunk_L]
# 35086                           [chunk_Pi, r_9, chunk_L]
# 35087                           [chunk_Pi, r_9, chunk_L]
#
#                                     listenerResponseList  \
# 37200  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 37201  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 37202  [h, l_1, v, v, r_1, l_10, r_6, v, r_6, v, l_5,...
# 37203  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 37204  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 37205  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37206  [v, r_6, v, l_5, chunk_C, r_4, h, r_9, h, l_4,...
# 37207  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37208  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37209  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37210  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 37211  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30528  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 30529  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 30530  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 30531  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 30532  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 30533          [v, r_6, v, l_5, h, r_4, h, r_9, chunk_8]
# 30534  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30535  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30536  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30537  [v, r_6, v, l_5, h, r_4, r_7, r_9, h, l_4, h, ...
# 30538  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 30539  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 23472  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 23473  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 23474  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 23475  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 23476  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 23477  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# ...                                                  ...
# 42186                           [chunk_8, r_9, chunk_8b]
# 42187                           [chunk_L, r_9, chunk_Pi]
# 42188                           [chunk_Pi, r_9, chunk_C]
# 42189                           [chunk_8, r_9, chunk_Pi]
# 42190                            [chunk_L, r_9, chunk_8]
# 42191                          [chunk_8b, r_9, chunk_Pi]
# 6156   [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 6157   [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 6158   [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 6159   [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 6160                   [chunk_8b, r_9, h, l_4, chunk_Pi]
# 6161                           [chunk_8b, r_9, chunk_Pi]
# 6162                            [chunk_8b, r_9, chunk_C]
# 6163                            [chunk_8, r_9, chunk_Pi]
# 6164                            [chunk_L, r_9, chunk_8b]
# 6165                           [chunk_8b, r_9, chunk_Pi]
# 6166                            [chunk_8b, r_9, chunk_L]
# 6167                            [chunk_8b, r_9, chunk_8]
# 35076  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35077  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35078  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35079  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 35080                  [chunk_Pi, r_9, h, l_4, chunk_8b]
# 35081                           [chunk_Pi, r_9, chunk_8]
# 35082                           [chunk_Pi, r_9, chunk_L]
# 35083                           [chunk_C, r_9, chunk_8b]
# 35084                            [chunk_C, r_9, chunk_8]
# 35085                           [chunk_8b, r_9, chunk_L]
# 35086                            [chunk_8, r_9, chunk_L]
# 35087                            [chunk_C, r_9, chunk_L]
#
#                                     speakerUtteranceList  \
# 37200  [place a horizontal block., move to the left b...
# 37201  [place a horizontal block., move to the left b...
# 37202  [place a horizontal block., move to the left b...
# 37203  [place a vertical block., move to the right by...
# 37204  [place a horizontal block., move to the left b...
# 37205  [place a vertical block., move to the right by...
# 37206  [place a vertical block., move to the right by...
# 37207  [place a vertical block., move to the right by...
# 37208  [place a vertical block., move to the right by...
# 37209  [place a vertical block., move to the right by...
# 37210  [place a vertical block., move to the right by...
# 37211  [place a vertical block., move to the right by...
# 30528  [place a horizontal block., move to the left b...
# 30529  [place a horizontal block., move to the left b...
# 30530  [place a horizontal block., move to the left b...
# 30531  [place a vertical block., move to the right by...
# 30532  [place a horizontal block., move to the left b...
# 30533  [place a vertical block., move to the right by...
# 30534  [place a vertical block., move to the right by...
# 30535  [place a vertical block., move to the right by...
# 30536  [place a vertical block., move to the right by...
# 30537  [place a vertical block., move to the right by...
# 30538  [place a vertical block., move to the right by...
# 30539  [place a vertical block., move to the right by...
# 23472  [place a horizontal block., move to the left b...
# 23473  [place a horizontal block., move to the left b...
# 23474  [place a horizontal block., move to the left b...
# 23475  [place a vertical block., move to the right by...
# 23476  [place a horizontal block., move to the left b...
# 23477  [place a vertical block., move to the right by...
# ...                                                  ...
# 42186             [blarp, move to the right by 9, blarp]
# 42187             [blarp, move to the right by 9, blarp]
# 42188             [blarp, move to the right by 9, blarp]
# 42189             [blarp, move to the right by 9, blarp]
# 42190             [blarp, move to the right by 9, blarp]
# 42191             [blarp, move to the right by 9, blarp]
# 6156   [place a horizontal block., move to the left b...
# 6157   [place a horizontal block., move to the left b...
# 6158   [place a horizontal block., move to the left b...
# 6159   [place a vertical block., move to the right by...
# 6160   [blarp, move to the right by 9, place a horizo...
# 6161                [blab, move to the right by 9, blah]
# 6162                [blah, move to the right by 9, blab]
# 6163                [blab, move to the right by 9, blah]
# 6164                [blah, move to the right by 9, blab]
# 6165                [blah, move to the right by 9, blah]
# 6166                [blah, move to the right by 9, blab]
# 6167                [blah, move to the right by 9, blab]
# 35076  [place a horizontal block., move to the left b...
# 35077  [place a horizontal block., move to the left b...
# 35078  [place a horizontal block., move to the left b...
# 35079  [place a vertical block., move to the right by...
# 35080  [blarp, move to the right by 9, place a horizo...
# 35081             [blarp, move to the right by 9, bloop]
# 35082             [bloop, move to the right by 9, bleep]
# 35083               [blah, move to the right by 9, blab]
# 35084             [blarp, move to the right by 9, bloop]
# 35085              [blah, move to the right by 9, bloop]
# 35086              [bleep, move to the right by 9, blab]
# 35087              [bleep, move to the right by 9, blab]
#
#                                    speakerUtteranceWords  \
# 37200  [place a horizontal block., move to the left b...
# 37201  [place a horizontal block., move to the left b...
# 37202  [place a horizontal block., move to the left b...
# 37203  [place a vertical block., move to the right by...
# 37204  [place a horizontal block., move to the left b...
# 37205  [place a vertical block., move to the right by...
# 37206  [place a vertical block., move to the right by...
# 37207  [place a vertical block., move to the right by...
# 37208  [place a vertical block., move to the right by...
# 37209  [place a vertical block., move to the right by...
# 37210  [place a vertical block., move to the right by...
# 37211  [place a vertical block., move to the right by...
# 30528  [place a horizontal block., move to the left b...
# 30529  [place a horizontal block., move to the left b...
# 30530  [place a horizontal block., move to the left b...
# 30531  [place a vertical block., move to the right by...
# 30532  [place a horizontal block., move to the left b...
# 30533  [place a vertical block., move to the right by...
# 30534  [place a vertical block., move to the right by...
# 30535  [place a vertical block., move to the right by...
# 30536  [place a vertical block., move to the right by...
# 30537  [place a vertical block., move to the right by...
# 30538  [place a vertical block., move to the right by...
# 30539  [place a vertical block., move to the right by...
# 23472  [place a horizontal block., move to the left b...
# 23473  [place a horizontal block., move to the left b...
# 23474  [place a horizontal block., move to the left b...
# 23475  [place a vertical block., move to the right by...
# 23476  [place a horizontal block., move to the left b...
# 23477  [place a vertical block., move to the right by...
# ...                                                  ...
# 42186             [blarp, move to the right by 9, blarp]
# 42187             [blarp, move to the right by 9, blarp]
# 42188             [blarp, move to the right by 9, blarp]
# 42189             [blarp, move to the right by 9, blarp]
# 42190             [blarp, move to the right by 9, blarp]
# 42191             [blarp, move to the right by 9, blarp]
# 6156   [place a horizontal block., move to the left b...
# 6157   [place a horizontal block., move to the left b...
# 6158   [place a horizontal block., move to the left b...
# 6159   [place a vertical block., move to the right by...
# 6160   [blarp, move to the right by 9, place a horizo...
# 6161                [blab, move to the right by 9, blah]
# 6162                [blah, move to the right by 9, blab]
# 6163                [blab, move to the right by 9, blah]
# 6164                [blah, move to the right by 9, blab]
# 6165                [blah, move to the right by 9, blah]
# 6166                [blah, move to the right by 9, blab]
# 6167                [blah, move to the right by 9, blab]
# 35076  [place a horizontal block., move to the left b...
# 35077  [place a horizontal block., move to the left b...
# 35078  [place a horizontal block., move to the left b...
# 35079  [place a vertical block., move to the right by...
# 35080  [blarp, move to the right by 9, place a horizo...
# 35081             [blarp, move to the right by 9, bloop]
# 35082             [bloop, move to the right by 9, bleep]
# 35083               [blah, move to the right by 9, blab]
# 35084             [blarp, move to the right by 9, bloop]
# 35085              [blah, move to the right by 9, bloop]
# 35086              [bleep, move to the right by 9, blab]
# 35087              [bleep, move to the right by 9, blab]
#
#                    intended_refs repetition  \
# 37200   [h, h, v, v, v, v, h, h]        1.0
# 37201   [h, h, v, v, h, v, v, h]        1.0
# 37202   [h, v, v, h, v, v, h, h]        1.0
# 37203  [v, v, h, h, chunk_8b, h]        2.0
# 37204   [h, v, v, h, h, h, v, v]        2.0
# 37205   [v, v, h, h, h, h, v, v]        2.0
# 37206   [v, v, h, h, h, h, v, v]        3.0
# 37207   [v, v, h, h, h, h, v, v]        3.0
# 37208   [v, v, h, h, h, h, v, v]        3.0
# 37209   [v, v, h, h, h, h, v, v]        4.0
# 37210   [v, v, h, h, h, h, v, v]        4.0
# 37211   [v, v, h, h, h, h, v, v]        4.0
# 30528   [h, h, v, v, v, v, h, h]        1.0
# 30529   [h, h, v, v, h, v, v, h]        1.0
# 30530   [h, v, v, h, v, v, h, h]        1.0
# 30531   [v, v, h, h, h, v, v, h]        2.0
# 30532   [h, v, v, h, h, h, v, v]        2.0
# 30533      [v, v, h, h, chunk_L]        2.0
# 30534   [v, v, h, h, h, h, v, v]        3.0
# 30535   [v, v, h, h, h, h, v, v]        3.0
# 30536   [v, v, h, h, h, h, v, v]        3.0
# 30537   [v, v, h, h, h, h, v, v]        4.0
# 30538   [v, v, h, h, h, h, v, v]        4.0
# 30539   [v, v, h, h, h, h, v, v]        4.0
# 23472   [h, h, v, v, v, v, h, h]        1.0
# 23473   [h, h, v, v, h, v, v, h]        1.0
# 23474   [h, v, v, h, v, v, h, h]        1.0
# 23475  [v, v, h, h, chunk_8b, h]        2.0
# 23476   [h, v, v, h, h, h, v, v]        2.0
# 23477   [v, v, h, h, h, h, v, v]        2.0
# ...                          ...        ...
# 42186        [chunk_Pi, chunk_L]        3.0
# 42187        [chunk_Pi, chunk_L]        3.0
# 42188        [chunk_Pi, chunk_L]        3.0
# 42189        [chunk_Pi, chunk_L]        4.0
# 42190        [chunk_Pi, chunk_L]        4.0
# 42191        [chunk_Pi, chunk_L]        4.0
# 6156    [h, h, v, v, h, v, v, h]        1.0
# 6157    [h, v, v, h, v, v, h, h]        1.0
# 6158    [h, h, v, v, v, v, h, h]        1.0
# 6159   [v, v, h, h, chunk_8b, h]        2.0
# 6160     [chunk_8b, h, chunk_Pi]        2.0
# 6161         [chunk_Pi, chunk_L]        2.0
# 6162         [chunk_Pi, chunk_L]        3.0
# 6163         [chunk_Pi, chunk_L]        3.0
# 6164         [chunk_Pi, chunk_L]        3.0
# 6165         [chunk_Pi, chunk_L]        4.0
# 6166         [chunk_Pi, chunk_L]        4.0
# 6167         [chunk_Pi, chunk_L]        4.0
# 35076   [h, h, v, v, h, v, v, h]        1.0
# 35077   [h, v, v, h, v, v, h, h]        1.0
# 35078   [h, h, v, v, v, v, h, h]        1.0
# 35079  [v, v, h, h, chunk_8b, h]        2.0
# 35080    [chunk_8b, h, chunk_Pi]        2.0
# 35081        [chunk_Pi, chunk_L]        2.0
# 35082        [chunk_Pi, chunk_L]        3.0
# 35083        [chunk_Pi, chunk_L]        3.0
# 35084        [chunk_Pi, chunk_L]        3.0
# 35085        [chunk_Pi, chunk_L]        4.0
# 35086        [chunk_Pi, chunk_L]        4.0
# 35087        [chunk_Pi, chunk_L]        4.0
#
#                               intended_abstraction_level intended_blocks  \
# 37200  [block, block, block, block, block, block, blo...               8
# 37201  [block, block, block, block, block, block, blo...               8
# 37202  [block, block, block, block, block, block, blo...               8
# 37203      [block, block, block, block, subtower, block]               5
# 37204  [block, block, block, block, block, block, blo...               8
# 37205  [block, block, block, block, block, block, blo...               8
# 37206  [block, block, block, block, block, block, blo...               8
# 37207  [block, block, block, block, block, block, blo...               8
# 37208  [block, block, block, block, block, block, blo...               8
# 37209  [block, block, block, block, block, block, blo...               8
# 37210  [block, block, block, block, block, block, blo...               8
# 37211  [block, block, block, block, block, block, blo...               8
# 30528  [block, block, block, block, block, block, blo...               8
# 30529  [block, block, block, block, block, block, blo...               8
# 30530  [block, block, block, block, block, block, blo...               8
# 30531  [block, block, block, block, block, block, blo...               8
# 30532  [block, block, block, block, block, block, blo...               8
# 30533                [block, block, block, block, tower]               4
# 30534  [block, block, block, block, block, block, blo...               8
# 30535  [block, block, block, block, block, block, blo...               8
# 30536  [block, block, block, block, block, block, blo...               8
# 30537  [block, block, block, block, block, block, blo...               8
# 30538  [block, block, block, block, block, block, blo...               8
# 30539  [block, block, block, block, block, block, blo...               8
# 23472  [block, block, block, block, block, block, blo...               8
# 23473  [block, block, block, block, block, block, blo...               8
# 23474  [block, block, block, block, block, block, blo...               8
# 23475      [block, block, block, block, subtower, block]               5
# 23476  [block, block, block, block, block, block, blo...               8
# 23477  [block, block, block, block, block, block, blo...               8
# ...                                                  ...             ...
# 42186                                     [tower, tower]               0
# 42187                                     [tower, tower]               0
# 42188                                     [tower, tower]               0
# 42189                                     [tower, tower]               0
# 42190                                     [tower, tower]               0
# 42191                                     [tower, tower]               0
# 6156   [block, block, block, block, block, block, blo...               8
# 6157   [block, block, block, block, block, block, blo...               8
# 6158   [block, block, block, block, block, block, blo...               8
# 6159       [block, block, block, block, subtower, block]               5
# 6160                            [subtower, block, tower]               1
# 6161                                      [tower, tower]               0
# 6162                                      [tower, tower]               0
# 6163                                      [tower, tower]               0
# 6164                                      [tower, tower]               0
# 6165                                      [tower, tower]               0
# 6166                                      [tower, tower]               0
# 6167                                      [tower, tower]               0
# 35076  [block, block, block, block, block, block, blo...               8
# 35077  [block, block, block, block, block, block, blo...               8
# 35078  [block, block, block, block, block, block, blo...               8
# 35079      [block, block, block, block, subtower, block]               5
# 35080                           [subtower, block, tower]               1
# 35081                                     [tower, tower]               0
# 35082                                     [tower, tower]               0
# 35083                                     [tower, tower]               0
# 35084                                     [tower, tower]               0
# 35085                                     [tower, tower]               0
# 35086                                     [tower, tower]               0
# 35087                                     [tower, tower]               0
#
#        intended_subtowers  intended_towers
# 37200                   0                0
# 37201                   0                0
# 37202                   0                0
# 37203                   1                0
# 37204                   0                0
# 37205                   0                0
# 37206                   0                0
# 37207                   0                0
# 37208                   0                0
# 37209                   0                0
# 37210                   0                0
# 37211                   0                0
# 30528                   0                0
# 30529                   0                0
# 30530                   0                0
# 30531                   0                0
# 30532                   0                0
# 30533                   0                1
# 30534                   0                0
# 30535                   0                0
# 30536                   0                0
# 30537                   0                0
# 30538                   0                0
# 30539                   0                0
# 23472                   0                0
# 23473                   0                0
# 23474                   0                0
# 23475                   1                0
# 23476                   0                0
# 23477                   0                0
# ...                   ...              ...
# 42186                   0                2
# 42187                   0                2
# 42188                   0                2
# 42189                   0                2
# 42190                   0                2
# 42191                   0                2
# 6156                    0                0
# 6157                    0                0
# 6158                    0                0
# 6159                    1                0
# 6160                    1                1
# 6161                    0                2
# 6162                    0                2
# 6163                    0                2
# 6164                    0                2
# 6165                    0                2
# 6166                    0                2
# 6167                    0                2
# 35076                   0                0
# 35077                   0                0
# 35078                   0                0
# 35079                   1                0
# 35080                   1                1
# 35081                   0                2
# 35082                   0                2
# 35083                   0                2
# 35084                   0                2
# 35085                   0                2
# 35086                   0                2
# 35087                   0                2
#
# [51744 rows x 21 columns]

# %%
def score_action_response(intended, executed):
    if intended==executed:
        if (intended.startswith('l_') or intended.startswith('r_')):
            return 0
        if (intended=='h') or (intended=='v'):
            return 1
        if (intended=='chunk_Pi') or (intended=='chunk_L') or (intended=='chunk_C'):
            return 4
        if (intended=='chunk_8') or (intended=='chunk_8b'):
            return 3
        if (intended=='chunk_9'):
            return 2
        else:
            print(intended)
    else:
        return 0

# %%
# plus one for every correct block in referring expressions 
df_model['soft_score'] = [sum(list(score_action_response(a,b) for (a,b) in zip(row['intendedSequenceList'], 
                                                                               row['listenerResponseList'])))\
                                                                  for i, row in df_model.iterrows()]

# %%
# soft accuracy
df_model['correct_action'] = [list(a == b for (a,b) in zip(row['intendedSequenceList'], row['listenerResponseList'])) for i, row in df_model.iterrows()]

# %%
df_model['prop_correct_action'] = df_model['correct_action'].apply(np.mean)

# %% [markdown]
# ## Referring expressions

# %%
df_model[df_model.beta.isin([0,0.2,0.4,0.6,0.8,1])]
# Out:
#       chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 3269         0    1          0      1   0.0         0      True
# 3270         0    1          0      1   0.0         1      True
# 3271         0    1          0      1   0.0         2     False
# 3272         0    1          0      1   0.0         3      True
# 3273         0    1          0      1   0.0         4      True
# 3274         0    1          0      1   0.0         5      True
# 3275         0    1          0      1   0.0         6     False
# 3276         0    1          0      1   0.0         7      True
# 3277         0    1          0      1   0.0         8      True
# 3278         0    1          0      1   0.0         9      True
# 3279         0    1          0      1   0.0        10      True
# 3280         0    1          0      1   0.0        11      True
# 2270        98    1          0      1   0.2         0      True
# 2271        98    1          0      1   0.2         1      True
# 2272        98    1          0      1   0.2         2      True
# 2273        98    1          0      1   0.2         3      True
# 2274        98    1          0      1   0.2         4      True
# 2275        98    1          0      1   0.2         5      True
# 2276        98    1          0      1   0.2         6     False
# 2277        98    1          0      1   0.2         7      True
# 2278        98    1          0      1   0.2         8     False
# 2279        98    1          0      1   0.2         9      True
# 2280        98    1          0      1   0.2        10     False
# 2281        98    1          0      1   0.2        11     False
# 3281         0    1          1      1   0.0         0      True
# 3282         0    1          1      1   0.0         1      True
# 3283         0    1          1      1   0.0         2      True
# 3284         0    1          1      1   0.0         3      True
# 3285         0    1          1      1   0.0         4      True
# 3286         0    1          1      1   0.0         5      True
# ...        ...  ...        ...    ...   ...       ...       ...
# 727        146   49          0      1   0.2         6     False
# 728        146   49          0      1   0.2         7     False
# 729        146   49          0      1   0.2         8     False
# 730        146   49          0      1   0.2         9      True
# 731        146   49          0      1   0.2        10     False
# 732        146   49          0      1   0.2        11     False
# 3305        48   49          1      1   0.0         0      True
# 3306        48   49          1      1   0.0         1      True
# 3307        48   49          1      1   0.0         2      True
# 3308        48   49          1      1   0.0         3      True
# 3309        48   49          1      1   0.0         4      True
# 3310        48   49          1      1   0.0         5     False
# 3311        48   49          1      1   0.0         6      True
# 3312        48   49          1      1   0.0         7      True
# 3313        48   49          1      1   0.0         8      True
# 3314        48   49          1      1   0.0         9      True
# 3315        48   49          1      1   0.0        10      True
# 3316        48   49          1      1   0.0        11      True
# 733        146   49          1      1   0.2         0      True
# 734        146   49          1      1   0.2         1      True
# 735        146   49          1      1   0.2         2      True
# 736        146   49          1      1   0.2         3      True
# 737        146   49          1      1   0.2         4      True
# 738        146   49          1      1   0.2         5     False
# 739        146   49          1      1   0.2         6      True
# 740        146   49          1      1   0.2         7     False
# 741        146   49          1      1   0.2         8     False
# 742        146   49          1      1   0.2         9     False
# 743        146   49          1      1   0.2        10     False
# 744        146   49          1      1   0.2        11      True
#
#       descriptionLength                         intendedSequence  \
# 3269                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 3270                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 3271                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 3272                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 3273                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 3274                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3275                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3276                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3277                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3278                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3279                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3280                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 2270                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 2271                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 2272                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 2273                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 2274                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 2275                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 2276                  8             chunk_Pi r_9 h l_4 h l_1 v v
# 2277                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 2278                  8             chunk_Pi r_9 h l_4 h l_1 v v
# 2279                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 2280                  9          v r_6 v l_5 h r_4 h r_9 chunk_L
# 2281                  9          v r_6 v l_5 h r_4 h r_9 chunk_L
# 3281                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 3282                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 3283                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 3284                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 3285                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 3286                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# ...                 ...                                      ...
# 727                   3                     chunk_Pi r_9 chunk_L
# 728                   8             chunk_Pi r_9 h l_4 h l_1 v v
# 729                   3                     chunk_Pi r_9 chunk_L
# 730                  14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 731                   3                     chunk_Pi r_9 chunk_L
# 732                   8             chunk_Pi r_9 h l_4 h l_1 v v
# 3305                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 3306                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 3307                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 3308                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 3309                 14  h l_1 v v r_9 h l_4 v r_6 v l_5 h r_4 h
# 3310                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3311                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3312                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3313                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3314                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3315                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 3316                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 733                  13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 734                  14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 735                  14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 736                  11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 737                   5              chunk_8b r_9 h l_4 chunk_Pi
# 738                   3                     chunk_Pi r_9 chunk_L
# 739                  14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 740                   3                     chunk_Pi r_9 chunk_L
# 741                   8             chunk_Pi r_9 h l_4 h l_1 v v
# 742                   8             chunk_Pi r_9 h l_4 h l_1 v v
# 743                   3                     chunk_Pi r_9 chunk_L
# 744                   8             chunk_Pi r_9 h l_4 h l_1 v v
#
#                                        speakerUtterance  ...  \
# 3269  place a horizontal block.~~~move to the left b...  ...
# 3270  place a horizontal block.~~~move to the left b...  ...
# 3271  place a horizontal block.~~~move to the left b...  ...
# 3272  place a vertical block.~~~move to the right by...  ...
# 3273  place a horizontal block.~~~move to the left b...  ...
# 3274  place a vertical block.~~~move to the right by...  ...
# 3275  place a vertical block.~~~move to the right by...  ...
# 3276  place a vertical block.~~~move to the right by...  ...
# 3277  place a vertical block.~~~move to the right by...  ...
# 3278  place a vertical block.~~~move to the right by...  ...
# 3279  place a vertical block.~~~move to the right by...  ...
# 3280  place a vertical block.~~~move to the right by...  ...
# 2270  place a horizontal block.~~~move to the left b...  ...
# 2271  place a horizontal block.~~~move to the left b...  ...
# 2272  place a horizontal block.~~~move to the left b...  ...
# 2273  place a vertical block.~~~move to the right by...  ...
# 2274  place a horizontal block.~~~move to the left b...  ...
# 2275  place a vertical block.~~~move to the right by...  ...
# 2276  bloop~~~move to the right by 9~~~place a horiz...  ...
# 2277  place a vertical block.~~~move to the right by...  ...
# 2278  blah~~~move to the right by 9~~~place a horizo...  ...
# 2279  place a vertical block.~~~move to the right by...  ...
# 2280  place a vertical block.~~~move to the right by...  ...
# 2281  place a vertical block.~~~move to the right by...  ...
# 3281  place a horizontal block.~~~move to the left b...  ...
# 3282  place a horizontal block.~~~move to the left b...  ...
# 3283  place a horizontal block.~~~move to the left b...  ...
# 3284  place a vertical block.~~~move to the right by...  ...
# 3285  place a horizontal block.~~~move to the left b...  ...
# 3286  place a vertical block.~~~move to the right by...  ...
# ...                                                 ...  ...
# 727               blah~~~move to the right by 9~~~blarp  ...
# 728   blah~~~move to the right by 9~~~place a horizo...  ...
# 729               blarp~~~move to the right by 9~~~blah  ...
# 730   place a vertical block.~~~move to the right by...  ...
# 731               blah~~~move to the right by 9~~~blarp  ...
# 732   blah~~~move to the right by 9~~~place a horizo...  ...
# 3305  place a horizontal block.~~~move to the left b...  ...
# 3306  place a horizontal block.~~~move to the left b...  ...
# 3307  place a horizontal block.~~~move to the left b...  ...
# 3308  place a vertical block.~~~move to the right by...  ...
# 3309  place a horizontal block.~~~move to the left b...  ...
# 3310  place a vertical block.~~~move to the right by...  ...
# 3311  place a vertical block.~~~move to the right by...  ...
# 3312  place a vertical block.~~~move to the right by...  ...
# 3313  place a vertical block.~~~move to the right by...  ...
# 3314  place a vertical block.~~~move to the right by...  ...
# 3315  place a vertical block.~~~move to the right by...  ...
# 3316  place a vertical block.~~~move to the right by...  ...
# 733   place a horizontal block.~~~move to the left b...  ...
# 734   place a horizontal block.~~~move to the left b...  ...
# 735   place a horizontal block.~~~move to the left b...  ...
# 736   place a vertical block.~~~move to the right by...  ...
# 737   blah~~~move to the right by 9~~~place a horizo...  ...
# 738               blarp~~~move to the right by 9~~~blah  ...
# 739   place a vertical block.~~~move to the right by...  ...
# 740                blah~~~move to the right by 9~~~blah  ...
# 741   blab~~~move to the right by 9~~~place a horizo...  ...
# 742   blarp~~~move to the right by 9~~~place a horiz...  ...
# 743               blarp~~~move to the right by 9~~~blah  ...
# 744   blarp~~~move to the right by 9~~~place a horiz...  ...
#
#                                   speakerUtteranceWords  \
# 3269  [place a horizontal block., move to the left b...
# 3270  [place a horizontal block., move to the left b...
# 3271  [place a horizontal block., move to the left b...
# 3272  [place a vertical block., move to the right by...
# 3273  [place a horizontal block., move to the left b...
# 3274  [place a vertical block., move to the right by...
# 3275  [place a vertical block., move to the right by...
# 3276  [place a vertical block., move to the right by...
# 3277  [place a vertical block., move to the right by...
# 3278  [place a vertical block., move to the right by...
# 3279  [place a vertical block., move to the right by...
# 3280  [place a vertical block., move to the right by...
# 2270  [place a horizontal block., move to the left b...
# 2271  [place a horizontal block., move to the left b...
# 2272  [place a horizontal block., move to the left b...
# 2273  [place a vertical block., move to the right by...
# 2274  [place a horizontal block., move to the left b...
# 2275  [place a vertical block., move to the right by...
# 2276  [bloop, move to the right by 9, place a horizo...
# 2277  [place a vertical block., move to the right by...
# 2278  [blah, move to the right by 9, place a horizon...
# 2279  [place a vertical block., move to the right by...
# 2280  [place a vertical block., move to the right by...
# 2281  [place a vertical block., move to the right by...
# 3281  [place a horizontal block., move to the left b...
# 3282  [place a horizontal block., move to the left b...
# 3283  [place a horizontal block., move to the left b...
# 3284  [place a vertical block., move to the right by...
# 3285  [place a horizontal block., move to the left b...
# 3286  [place a vertical block., move to the right by...
# ...                                                 ...
# 727               [blah, move to the right by 9, blarp]
# 728   [blah, move to the right by 9, place a horizon...
# 729               [blarp, move to the right by 9, blah]
# 730   [place a vertical block., move to the right by...
# 731               [blah, move to the right by 9, blarp]
# 732   [blah, move to the right by 9, place a horizon...
# 3305  [place a horizontal block., move to the left b...
# 3306  [place a horizontal block., move to the left b...
# 3307  [place a horizontal block., move to the left b...
# 3308  [place a vertical block., move to the right by...
# 3309  [place a horizontal block., move to the left b...
# 3310  [place a vertical block., move to the right by...
# 3311  [place a vertical block., move to the right by...
# 3312  [place a vertical block., move to the right by...
# 3313  [place a vertical block., move to the right by...
# 3314  [place a vertical block., move to the right by...
# 3315  [place a vertical block., move to the right by...
# 3316  [place a vertical block., move to the right by...
# 733   [place a horizontal block., move to the left b...
# 734   [place a horizontal block., move to the left b...
# 735   [place a horizontal block., move to the left b...
# 736   [place a vertical block., move to the right by...
# 737   [blah, move to the right by 9, place a horizon...
# 738               [blarp, move to the right by 9, blah]
# 739   [place a vertical block., move to the right by...
# 740                [blah, move to the right by 9, blah]
# 741   [blab, move to the right by 9, place a horizon...
# 742   [blarp, move to the right by 9, place a horizo...
# 743               [blarp, move to the right by 9, blah]
# 744   [blarp, move to the right by 9, place a horizo...
#
#                   intended_refs repetition  \
# 3269   [h, h, v, v, v, v, h, h]        1.0
# 3270   [h, h, v, v, h, v, v, h]        1.0
# 3271   [h, v, v, h, v, v, h, h]        1.0
# 3272  [v, v, h, h, chunk_8b, h]        2.0
# 3273   [h, v, v, h, h, h, v, v]        2.0
# 3274   [v, v, h, h, h, h, v, v]        2.0
# 3275   [v, v, h, h, h, h, v, v]        3.0
# 3276   [v, v, h, h, h, h, v, v]        3.0
# 3277   [v, v, h, h, h, h, v, v]        3.0
# 3278   [v, v, h, h, h, h, v, v]        4.0
# 3279   [v, v, h, h, h, h, v, v]        4.0
# 3280   [v, v, h, h, h, h, v, v]        4.0
# 2270   [h, h, v, v, v, v, h, h]        1.0
# 2271   [h, h, v, v, h, v, v, h]        1.0
# 2272   [h, v, v, h, v, v, h, h]        1.0
# 2273  [v, v, h, h, chunk_8b, h]        2.0
# 2274   [h, v, v, h, h, h, v, v]        2.0
# 2275   [v, v, h, h, h, h, v, v]        2.0
# 2276     [chunk_Pi, h, h, v, v]        3.0
# 2277   [v, v, h, h, h, h, v, v]        3.0
# 2278     [chunk_Pi, h, h, v, v]        3.0
# 2279   [v, v, h, h, h, h, v, v]        4.0
# 2280      [v, v, h, h, chunk_L]        4.0
# 2281      [v, v, h, h, chunk_L]        4.0
# 3281   [h, h, v, v, v, v, h, h]        1.0
# 3282   [h, h, v, v, h, v, v, h]        1.0
# 3283   [h, v, v, h, v, v, h, h]        1.0
# 3284  [v, v, h, h, chunk_8b, h]        2.0
# 3285   [h, v, v, h, h, h, v, v]        2.0
# 3286   [v, v, h, h, h, h, v, v]        2.0
# ...                         ...        ...
# 727         [chunk_Pi, chunk_L]        3.0
# 728      [chunk_Pi, h, h, v, v]        3.0
# 729         [chunk_Pi, chunk_L]        3.0
# 730    [v, v, h, h, h, h, v, v]        4.0
# 731         [chunk_Pi, chunk_L]        4.0
# 732      [chunk_Pi, h, h, v, v]        4.0
# 3305   [h, h, v, v, h, v, v, h]        1.0
# 3306   [h, v, v, h, v, v, h, h]        1.0
# 3307   [h, h, v, v, v, v, h, h]        1.0
# 3308  [v, v, h, h, chunk_8b, h]        2.0
# 3309   [h, v, v, h, v, v, h, h]        2.0
# 3310   [v, v, h, h, h, h, v, v]        2.0
# 3311   [v, v, h, h, h, h, v, v]        3.0
# 3312   [v, v, h, h, h, h, v, v]        3.0
# 3313   [v, v, h, h, h, h, v, v]        3.0
# 3314   [v, v, h, h, h, h, v, v]        4.0
# 3315   [v, v, h, h, h, h, v, v]        4.0
# 3316   [v, v, h, h, h, h, v, v]        4.0
# 733    [h, h, v, v, h, v, v, h]        1.0
# 734    [h, v, v, h, v, v, h, h]        1.0
# 735    [h, h, v, v, v, v, h, h]        1.0
# 736   [v, v, h, h, chunk_8b, h]        2.0
# 737     [chunk_8b, h, chunk_Pi]        2.0
# 738         [chunk_Pi, chunk_L]        2.0
# 739    [v, v, h, h, h, h, v, v]        3.0
# 740         [chunk_Pi, chunk_L]        3.0
# 741      [chunk_Pi, h, h, v, v]        3.0
# 742      [chunk_Pi, h, h, v, v]        4.0
# 743         [chunk_Pi, chunk_L]        4.0
# 744      [chunk_Pi, h, h, v, v]        4.0
#
#                              intended_abstraction_level intended_blocks  \
# 3269  [block, block, block, block, block, block, blo...               8
# 3270  [block, block, block, block, block, block, blo...               8
# 3271  [block, block, block, block, block, block, blo...               8
# 3272      [block, block, block, block, subtower, block]               5
# 3273  [block, block, block, block, block, block, blo...               8
# 3274  [block, block, block, block, block, block, blo...               8
# 3275  [block, block, block, block, block, block, blo...               8
# 3276  [block, block, block, block, block, block, blo...               8
# 3277  [block, block, block, block, block, block, blo...               8
# 3278  [block, block, block, block, block, block, blo...               8
# 3279  [block, block, block, block, block, block, blo...               8
# 3280  [block, block, block, block, block, block, blo...               8
# 2270  [block, block, block, block, block, block, blo...               8
# 2271  [block, block, block, block, block, block, blo...               8
# 2272  [block, block, block, block, block, block, blo...               8
# 2273      [block, block, block, block, subtower, block]               5
# 2274  [block, block, block, block, block, block, blo...               8
# 2275  [block, block, block, block, block, block, blo...               8
# 2276                [tower, block, block, block, block]               4
# 2277  [block, block, block, block, block, block, blo...               8
# 2278                [tower, block, block, block, block]               4
# 2279  [block, block, block, block, block, block, blo...               8
# 2280                [block, block, block, block, tower]               4
# 2281                [block, block, block, block, tower]               4
# 3281  [block, block, block, block, block, block, blo...               8
# 3282  [block, block, block, block, block, block, blo...               8
# 3283  [block, block, block, block, block, block, blo...               8
# 3284      [block, block, block, block, subtower, block]               5
# 3285  [block, block, block, block, block, block, blo...               8
# 3286  [block, block, block, block, block, block, blo...               8
# ...                                                 ...             ...
# 727                                      [tower, tower]               0
# 728                 [tower, block, block, block, block]               4
# 729                                      [tower, tower]               0
# 730   [block, block, block, block, block, block, blo...               8
# 731                                      [tower, tower]               0
# 732                 [tower, block, block, block, block]               4
# 3305  [block, block, block, block, block, block, blo...               8
# 3306  [block, block, block, block, block, block, blo...               8
# 3307  [block, block, block, block, block, block, blo...               8
# 3308      [block, block, block, block, subtower, block]               5
# 3309  [block, block, block, block, block, block, blo...               8
# 3310  [block, block, block, block, block, block, blo...               8
# 3311  [block, block, block, block, block, block, blo...               8
# 3312  [block, block, block, block, block, block, blo...               8
# 3313  [block, block, block, block, block, block, blo...               8
# 3314  [block, block, block, block, block, block, blo...               8
# 3315  [block, block, block, block, block, block, blo...               8
# 3316  [block, block, block, block, block, block, blo...               8
# 733   [block, block, block, block, block, block, blo...               8
# 734   [block, block, block, block, block, block, blo...               8
# 735   [block, block, block, block, block, block, blo...               8
# 736       [block, block, block, block, subtower, block]               5
# 737                            [subtower, block, tower]               1
# 738                                      [tower, tower]               0
# 739   [block, block, block, block, block, block, blo...               8
# 740                                      [tower, tower]               0
# 741                 [tower, block, block, block, block]               4
# 742                 [tower, block, block, block, block]               4
# 743                                      [tower, tower]               0
# 744                 [tower, block, block, block, block]               4
#
#      intended_subtowers  intended_towers soft_score  \
# 3269                  0                0          8
# 3270                  0                0          8
# 3271                  0                0          7
# 3272                  1                0          8
# 3273                  0                0          8
# 3274                  0                0          8
# 3275                  0                0          7
# 3276                  0                0          8
# 3277                  0                0          8
# 3278                  0                0          8
# 3279                  0                0          8
# 3280                  0                0          8
# 2270                  0                0          8
# 2271                  0                0          8
# 2272                  0                0          8
# 2273                  1                0          8
# 2274                  0                0          8
# 2275                  0                0          8
# 2276                  0                1          4
# 2277                  0                0          8
# 2278                  0                1          4
# 2279                  0                0          8
# 2280                  0                1          4
# 2281                  0                1          4
# 3281                  0                0          8
# 3282                  0                0          8
# 3283                  0                0          8
# 3284                  1                0          8
# 3285                  0                0          8
# 3286                  0                0          8
# ...                 ...              ...        ...
# 727                   0                2          0
# 728                   0                1          4
# 729                   0                2          4
# 730                   0                0          8
# 731                   0                2          0
# 732                   0                1          4
# 3305                  0                0          8
# 3306                  0                0          8
# 3307                  0                0          8
# 3308                  1                0          8
# 3309                  0                0          8
# 3310                  0                0          8
# 3311                  0                0          8
# 3312                  0                0          8
# 3313                  0                0          8
# 3314                  0                0          8
# 3315                  0                0          8
# 3316                  0                0          8
# 733                   0                0          8
# 734                   0                0          8
# 735                   0                0          8
# 736                   1                0          8
# 737                   1                1          8
# 738                   0                2          0
# 739                   0                0          8
# 740                   0                2          4
# 741                   0                1          4
# 742                   0                1          4
# 743                   0                2          4
# 744                   0                1          8
#
#                                          correct_action  prop_correct_action
# 3269  [True, True, True, True, True, True, True, Tru...             1.000000
# 3270  [True, True, True, True, True, True, True, Tru...             1.000000
# 3271  [True, True, True, True, True, False, True, Tr...             0.928571
# 3272  [True, True, True, True, True, True, True, Tru...             1.000000
# 3273  [True, True, True, True, True, True, True, Tru...             1.000000
# 3274  [True, True, True, True, True, True, True, Tru...             1.000000
# 3275  [True, True, True, True, False, True, True, Tr...             0.928571
# 3276  [True, True, True, True, True, True, True, Tru...             1.000000
# 3277  [True, True, True, True, True, True, True, Tru...             1.000000
# 3278  [True, True, True, True, True, True, True, Tru...             1.000000
# 3279  [True, True, True, True, True, True, True, Tru...             1.000000
# 3280  [True, True, True, True, True, True, True, Tru...             1.000000
# 2270  [True, True, True, True, True, True, True, Tru...             1.000000
# 2271  [True, True, True, True, True, True, True, Tru...             1.000000
# 2272  [True, True, True, True, True, True, True, Tru...             1.000000
# 2273  [True, True, True, True, True, True, True, Tru...             1.000000
# 2274  [True, True, True, True, True, True, True, Tru...             1.000000
# 2275  [True, True, True, True, True, True, True, Tru...             1.000000
# 2276  [False, True, True, True, True, True, True, True]             0.875000
# 2277  [True, True, True, True, True, True, True, Tru...             1.000000
# 2278  [False, True, True, True, True, True, True, True]             0.875000
# 2279  [True, True, True, True, True, True, True, Tru...             1.000000
# 2280  [True, False, True, True, True, True, True, Tr...             0.777778
# 2281  [True, True, True, True, True, True, True, Tru...             0.888889
# 3281  [True, True, True, True, True, True, True, Tru...             1.000000
# 3282  [True, True, True, True, True, True, True, Tru...             1.000000
# 3283  [True, True, True, True, True, True, True, Tru...             1.000000
# 3284  [True, True, True, True, True, True, True, Tru...             1.000000
# 3285  [True, True, True, True, True, True, True, Tru...             1.000000
# 3286  [True, True, True, True, True, True, True, Tru...             1.000000
# ...                                                 ...                  ...
# 727                                [False, True, False]             0.333333
# 728   [False, True, True, True, True, True, True, True]             0.875000
# 729                                 [True, True, False]             0.666667
# 730   [True, True, True, True, True, True, True, Tru...             1.000000
# 731                                [False, True, False]             0.333333
# 732   [False, True, True, True, True, True, True, True]             0.875000
# 3305  [True, True, True, True, True, True, True, Tru...             1.000000
# 3306  [True, True, True, True, True, True, True, Tru...             1.000000
# 3307  [True, True, True, True, True, True, True, Tru...             1.000000
# 3308  [True, True, True, True, True, True, True, Tru...             1.000000
# 3309  [True, True, True, True, True, True, True, Tru...             1.000000
# 3310  [True, True, True, True, True, True, True, Tru...             0.928571
# 3311  [True, True, True, True, True, True, True, Tru...             1.000000
# 3312  [True, True, True, True, True, True, True, Tru...             1.000000
# 3313  [True, True, True, True, True, True, True, Tru...             1.000000
# 3314  [True, True, True, True, True, True, True, Tru...             1.000000
# 3315  [True, True, True, True, True, True, True, Tru...             1.000000
# 3316  [True, True, True, True, True, True, True, Tru...             1.000000
# 733   [True, True, True, True, True, True, True, Tru...             1.000000
# 734   [True, True, True, True, True, True, True, Tru...             1.000000
# 735   [True, True, True, True, True, True, True, Tru...             1.000000
# 736   [True, True, True, True, True, True, True, Tru...             1.000000
# 737                      [True, True, True, True, True]             1.000000
# 738                                [False, True, False]             0.333333
# 739   [True, True, True, True, True, True, True, Tru...             1.000000
# 740                                 [True, True, False]             0.666667
# 741   [False, True, True, True, True, True, True, True]             0.875000
# 742   [False, True, True, True, True, True, True, True]             0.875000
# 743                                 [True, True, False]             0.666667
# 744    [True, True, True, True, True, True, True, True]             1.000000
#
# [2352 rows x 24 columns]

# %%
black = sns.light_palette("#000000", reverse=False, as_cmap=True)
red = sns.light_palette("#FF0000", reverse=False, as_cmap=True)
green = sns.light_palette("#008000", reverse=False, as_cmap=True)

# %%
fig = plt.figure(figsize=(6,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 3})
sns.lineplot(data=df_model, x='repetition', y='intended_blocks', hue='beta', palette=black)
sns.lineplot(data=df_model, x='repetition', y='intended_subtowers', hue='beta', palette=red)
g = sns.lineplot(data=df_model, x='repetition', y='intended_towers', hue='beta', palette=green)
g.legend().remove()
g.set(xlim=(0.8,4.2))
g.set(xticks=[1,2,3,4])
g.set(xticklabels=['1','2','3','4'])
g.set_yticklabels([str(int(y)) for y in g.get_yticks()], size = 25)
g.set_xticklabels([str(int(x)) for x in g.get_xticks()], size = 25)
g.set(ylabel='')
g.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
df_model_avg = df_model.groupby(['ppt','alpha','beta','repetition']).mean().reset_index()

# %%
# revised plot

subset = df_model_avg[df_model_avg.beta <= 0.5]

fig = plt.figure(figsize=(6,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 3})
sns.lineplot(data=subset, x='repetition', y='intended_blocks', hue='beta', palette=black)
sns.lineplot(data=subset, x='repetition', y='intended_subtowers', hue='beta', palette=red)
g = sns.lineplot(data=subset, x='repetition', y='intended_towers', hue='beta', palette=green)
g.legend().remove()
g.set(xlim=(0.8,4.2))
g.set(xticks=[1,2,3,4])
g.set(xticklabels=['1','2','3','4'])
g.set_yticklabels([str(int(y)) for y in g.get_yticks()], size = 25)
g.set_xticklabels([str(int(x)) for x in g.get_xticks()], size = 25)
g.set(ylabel='')
g.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
#fig.savefig('../../figures/cogsci2021_model_expressions_all_seqs.pdf', transparent=False, bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'soft_score')
plt.legend(bbox_to_anchor=(1.04, 1))

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'repetition', 'intended_blocks')
# g.map(sns.lineplot, 'trialNum', 'intended_subtowers')
g.map(sns.lineplot, 'repetition', 'intended_towers')

# %%
#fig.savefig('../../figures/cogsci2021_model_expressions.pdf', transparent=False, bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Accuracy

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='accuracy', x='trialNum', hue='alpha')

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='accuracy', x='trialNum', hue='beta')

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'accuracy')
plt.legend(bbox_to_anchor=(1.04, 1))

# %%
fig = plt.figure(figsize=(12,10))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='beta', col_wrap=5, hue='alpha')
g.map(sns.lineplot, 'trialNum', 'accuracy')

# %% [markdown]
# ## Number of instructions

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='descriptionLength', x='trialNum', hue='alpha')

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'descriptionLength')
