# %%
import os
import sys
import urllib, io
os.getcwd()
sys.path.append("..")
sys.path.append("../utils")
sys.path.append("../analysis/utils")
import glob

import numpy as np
import scipy.stats as stats
import pandas as pd

import pymongo as pm
from collections import Counter
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

# %%
## directory & file hierarchy
proj_dir = os.path.abspath('..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir =  os.path.abspath('.')
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
json_dir = os.path.join(results_dir,'json')
exp_dir = os.path.abspath(os.path.join(proj_dir,'behavioral_experiments'))
png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %% [markdown]
# ### Import model results

# %%
model_output_dir = os.path.abspath('../language_output/')

all_files = glob.glob(model_output_dir + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df_model = pd.concat(li, axis=0, ignore_index=True).sort_values(['ppt','iteration','chainNum','alpha','beta','trialNum'])

# # swap mislabeled columns
# intendedSequence = df_model['speakerUtterance'].copy()
# speakerUtterance = df_model['intendedSequence'].copy()
# df_model['speakerUtterance'] = speakerUtterance
# df_model['intendedSequence'] = intendedSequence

# %% [markdown]
# - iterationName: 0 to 99
# - chainNum: index for parameter pair
# - alpha:
# - beta:

# %%
df_model
# Out:
#        chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 35352         0    1          0      1   0.0         0      True
# 35353         0    1          0      1   0.0         1      True
# 35354         0    1          0      1   0.0         2      True
# 35355         0    1          0      1   0.0         3      True
# 35356         0    1          0      1   0.0         4     False
# ...         ...  ...        ...    ...   ...       ...       ...
# 11491      2155   49          1     64   1.0         7     False
# 11492      2155   49          1     64   1.0         8     False
# 11493      2155   49          1     64   1.0         9     False
# 11494      2155   49          1     64   1.0        10     False
# 11495      2155   49          1     64   1.0        11     False
#
#        descriptionLength                         intendedSequence  \
# 35352                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35353                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35354                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35355                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35356                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# ...                  ...                                      ...
# 11491                  3                     chunk_L r_12 chunk_C
# 11492                  3                     chunk_C r_6 chunk_Pi
# 11493                  3                     chunk_C r_12 chunk_L
# 11494                  3                     chunk_Pi r_7 chunk_C
# 11495                  3                     chunk_Pi r_9 chunk_L
#
#                                         speakerUtterance  \
# 35352  place a horizontal block.~~~move to the left b...
# 35353  place a horizontal block.~~~move to the left b...
# 35354  place a horizontal block.~~~move to the left b...
# 35355  place a vertical block.~~~move to the right by...
# 35356  place a horizontal block.~~~move to the left b...
# ...                                                  ...
# 11491            bloop~~~move to the right by 12~~~bloop
# 11492             bloop~~~move to the right by 6~~~bleep
# 11493            bloop~~~move to the right by 12~~~bloop
# 11494              blah~~~move to the right by 7~~~bleep
# 11495              bleep~~~move to the right by 9~~~blah
#
#                               listenerResponse
# 35352  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35353     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35354  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35355   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35356   h l_1 v v r_1 h r_12 r_5 l_4 h l_1 v v
# ...                                        ...
# 11491                   chunk_Pi r_12 chunk_8b
# 11492                     chunk_8b r_0 chunk_C
# 11493                   chunk_8b r_12 chunk_8b
# 11494                      chunk_C r_7 chunk_8
# 11495                     chunk_8b r_9 chunk_L
#
# [51744 rows x 11 columns]

# %%
def get_intended_refs(intendedSequenceList):
    return[exp for exp in intendedSequenceList if ((not exp.startswith('r_')) & ( not exp.startswith('l_')))]

# %%
# preprocessing

df_model['intendedSequenceList'] = df_model['intendedSequence'].apply(lambda string: string.split(' '))
df_model['listenerResponseList'] = df_model['listenerResponse'].apply(lambda string: string.split(' '))
df_model['speakerUtteranceList'] = df_model['speakerUtterance'].apply(lambda string: string.split('~~~'))

df_model['speakerUtteranceWords'] = df_model['speakerUtterance'].apply(lambda string: string.split('~~~'))
df_model['intended_refs'] = df_model['intendedSequenceList'].apply(get_intended_refs)

#checks
assert np.all(df_model['intendedSequenceList'].apply(len) == df_model['descriptionLength'])
assert np.all(df_model['speakerUtteranceList'].apply(len) == df_model['descriptionLength'])

# %%
df_model['repetition'] = np.floor((df_model['trialNum']/3))+1

# %%
intended_abstraction_levels = {
    'v': 'block',
    'h': 'block',
    'chunk_L': 'tower',
    'chunk_Pi': 'tower',
    'chunk_C': 'tower',
    'chunk_8': 'subtower',
    'chunk_8b': 'subtower',
    'chunk_9': 'subtower'
}

# %%
def abstraction_level(intended_ref):
    assert intended_ref in intended_abstraction_levels.keys()
    if intended_ref in intended_abstraction_levels.keys():
        return intended_abstraction_levels[intended_ref]
    else:
        print(intended_ref)
        return 'UNKNOWN'

# %%
df_model['intended_abstraction_level'] = \
        df_model['intended_refs'].apply(lambda intended_refs: [abstraction_level(ref) for ref in intended_refs])

# %%
df_model['intended_blocks'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['block'])
df_model['intended_subtowers'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['subtower'])
df_model['intended_towers'] = df_model['intended_abstraction_level'].apply(lambda x: Counter(x)['tower'])

# %%
df_model
# Out:
#        chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 27696         0    1          0      1   0.0         0      True
# 27697         0    1          0      1   0.0         1      True
# 27698         0    1          0      1   0.0         2      True
# 27699         0    1          0      1   0.0         3      True
# 27700         0    1          0      1   0.0         4     False
# 27701         0    1          0      1   0.0         5      True
# 27702         0    1          0      1   0.0         6      True
# 27703         0    1          0      1   0.0         7      True
# 27704         0    1          0      1   0.0         8      True
# 27705         0    1          0      1   0.0         9      True
# 27706         0    1          0      1   0.0        10      True
# 27707         0    1          0      1   0.0        11     False
# 35808        49    1          0      1   0.1         0      True
# 35809        49    1          0      1   0.1         1      True
# 35810        49    1          0      1   0.1         2      True
# 35811        49    1          0      1   0.1         3      True
# 35812        49    1          0      1   0.1         4      True
# 35813        49    1          0      1   0.1         5      True
# 35814        49    1          0      1   0.1         6      True
# 35815        49    1          0      1   0.1         7      True
# 35816        49    1          0      1   0.1         8      True
# 35817        49    1          0      1   0.1         9      True
# 35818        49    1          0      1   0.1        10      True
# 35819        49    1          0      1   0.1        11      True
# 35760        98    1          0      1   0.2         0      True
# 35761        98    1          0      1   0.2         1      True
# 35762        98    1          0      1   0.2         2      True
# 35763        98    1          0      1   0.2         3     False
# 35764        98    1          0      1   0.2         4      True
# 35765        98    1          0      1   0.2         5      True
# ...         ...  ...        ...    ...   ...       ...       ...
# 41490      2057   49          1     64   0.8         6     False
# 41491      2057   49          1     64   0.8         7     False
# 41492      2057   49          1     64   0.8         8     False
# 41493      2057   49          1     64   0.8         9     False
# 41494      2057   49          1     64   0.8        10     False
# 41495      2057   49          1     64   0.8        11     False
# 39996      2106   49          1     64   0.9         0     False
# 39997      2106   49          1     64   0.9         1      True
# 39998      2106   49          1     64   0.9         2     False
# 39999      2106   49          1     64   0.9         3      True
# 40000      2106   49          1     64   0.9         4     False
# 40001      2106   49          1     64   0.9         5     False
# 40002      2106   49          1     64   0.9         6     False
# 40003      2106   49          1     64   0.9         7     False
# 40004      2106   49          1     64   0.9         8     False
# 40005      2106   49          1     64   0.9         9     False
# 40006      2106   49          1     64   0.9        10     False
# 40007      2106   49          1     64   0.9        11     False
# 17196      2155   49          1     64   1.0         0      True
# 17197      2155   49          1     64   1.0         1      True
# 17198      2155   49          1     64   1.0         2      True
# 17199      2155   49          1     64   1.0         3      True
# 17200      2155   49          1     64   1.0         4      True
# 17201      2155   49          1     64   1.0         5     False
# 17202      2155   49          1     64   1.0         6     False
# 17203      2155   49          1     64   1.0         7     False
# 17204      2155   49          1     64   1.0         8     False
# 17205      2155   49          1     64   1.0         9     False
# 17206      2155   49          1     64   1.0        10     False
# 17207      2155   49          1     64   1.0        11     False
#
#        descriptionLength                         intendedSequence  \
# 27696                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 27697                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 27698                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 27699                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 27700                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 27701                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 27702                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 27703                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 27704                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 27705                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 27706                 14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 27707                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 35808                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35809                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35810                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35811                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35812                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 35813                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 35814                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35815                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35816                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35817                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 35818                 14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 35819                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 35760                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35761                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35762                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35763                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35764                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 35765                  8             chunk_Pi r_9 h l_4 h l_1 v v
# ...                  ...                                      ...
# 41490                  3                     chunk_L r_9 chunk_Pi
# 41491                  3                     chunk_L r_12 chunk_C
# 41492                  3                     chunk_C r_6 chunk_Pi
# 41493                  3                     chunk_C r_12 chunk_L
# 41494                  3                     chunk_Pi r_7 chunk_C
# 41495                  3                     chunk_Pi r_9 chunk_L
# 39996                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 39997                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 39998                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 39999                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 40000                  5              chunk_8b r_9 h l_4 chunk_Pi
# 40001                  3                     chunk_C r_12 chunk_L
# 40002                  3                     chunk_L r_9 chunk_Pi
# 40003                  3                     chunk_L r_12 chunk_C
# 40004                  3                     chunk_C r_6 chunk_Pi
# 40005                  3                     chunk_C r_12 chunk_L
# 40006                  3                     chunk_Pi r_7 chunk_C
# 40007                  3                     chunk_Pi r_9 chunk_L
# 17196                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 17197                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 17198                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 17199                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 17200                  5              chunk_8b r_9 h l_4 chunk_Pi
# 17201                  3                     chunk_C r_12 chunk_L
# 17202                  3                     chunk_L r_9 chunk_Pi
# 17203                  3                     chunk_L r_12 chunk_C
# 17204                  3                     chunk_C r_6 chunk_Pi
# 17205                  3                     chunk_C r_12 chunk_L
# 17206                  3                     chunk_Pi r_7 chunk_C
# 17207                  3                     chunk_Pi r_9 chunk_L
#
#                                         speakerUtterance  ...  \
# 27696  place a horizontal block.~~~move to the left b...  ...
# 27697  place a horizontal block.~~~move to the left b...  ...
# 27698  place a horizontal block.~~~move to the left b...  ...
# 27699  place a vertical block.~~~move to the right by...  ...
# 27700  place a horizontal block.~~~move to the left b...  ...
# 27701  place a vertical block.~~~move to the right by...  ...
# 27702  place a horizontal block.~~~move to the left b...  ...
# 27703  place a horizontal block.~~~move to the left b...  ...
# 27704  place a horizontal block.~~~move to the left b...  ...
# 27705  place a horizontal block.~~~move to the left b...  ...
# 27706  place a vertical block.~~~move to the right by...  ...
# 27707  place a vertical block.~~~move to the right by...  ...
# 35808  place a horizontal block.~~~move to the left b...  ...
# 35809  place a horizontal block.~~~move to the left b...  ...
# 35810  place a horizontal block.~~~move to the left b...  ...
# 35811  place a vertical block.~~~move to the right by...  ...
# 35812  place a horizontal block.~~~move to the left b...  ...
# 35813  place a vertical block.~~~move to the right by...  ...
# 35814  place a horizontal block.~~~move to the left b...  ...
# 35815  place a horizontal block.~~~move to the left b...  ...
# 35816  place a horizontal block.~~~move to the left b...  ...
# 35817  place a horizontal block.~~~move to the left b...  ...
# 35818  place a vertical block.~~~move to the right by...  ...
# 35819  place a vertical block.~~~move to the right by...  ...
# 35760  place a horizontal block.~~~move to the left b...  ...
# 35761  place a horizontal block.~~~move to the left b...  ...
# 35762  place a horizontal block.~~~move to the left b...  ...
# 35763  place a vertical block.~~~move to the right by...  ...
# 35764  place a horizontal block.~~~move to the left b...  ...
# 35765  bloop~~~move to the right by 9~~~place a horiz...  ...
# ...                                                  ...  ...
# 41490             bleep~~~move to the right by 9~~~bleep  ...
# 41491            bleep~~~move to the right by 12~~~bleep  ...
# 41492             bleep~~~move to the right by 6~~~bleep  ...
# 41493            bleep~~~move to the right by 12~~~bleep  ...
# 41494             bleep~~~move to the right by 7~~~bleep  ...
# 41495             bleep~~~move to the right by 9~~~bleep  ...
# 39996  place a horizontal block.~~~move to the left b...  ...
# 39997  place a horizontal block.~~~move to the left b...  ...
# 39998  place a horizontal block.~~~move to the left b...  ...
# 39999  place a vertical block.~~~move to the right by...  ...
# 40000  bleep~~~move to the right by 9~~~place a horiz...  ...
# 40001            bleep~~~move to the right by 12~~~bleep  ...
# 40002              bleep~~~move to the right by 9~~~blab  ...
# 40003             blab~~~move to the right by 12~~~bleep  ...
# 40004             bleep~~~move to the right by 6~~~bleep  ...
# 40005            bleep~~~move to the right by 12~~~bleep  ...
# 40006              bleep~~~move to the right by 7~~~blab  ...
# 40007              blab~~~move to the right by 9~~~bleep  ...
# 17196  place a horizontal block.~~~move to the left b...  ...
# 17197  place a horizontal block.~~~move to the left b...  ...
# 17198  place a horizontal block.~~~move to the left b...  ...
# 17199  place a vertical block.~~~move to the right by...  ...
# 17200  blah~~~move to the right by 9~~~place a horizo...  ...
# 17201             blah~~~move to the right by 12~~~blarp  ...
# 17202             blarp~~~move to the right by 9~~~bloop  ...
# 17203            bloop~~~move to the right by 12~~~bloop  ...
# 17204             bloop~~~move to the right by 6~~~bleep  ...
# 17205            bloop~~~move to the right by 12~~~bloop  ...
# 17206              blah~~~move to the right by 7~~~bleep  ...
# 17207              bleep~~~move to the right by 9~~~blah  ...
#
#                                     intendedSequenceList  \
# 27696  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 27697  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 27698  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 27699  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 27700  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 27701  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 27702  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 27703  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 27704  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 27705  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 27706  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 27707  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 35808  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35809  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35810  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35811  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 35812  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35813  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 35814  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35815  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35816  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35817  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35818  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 35819  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 35760  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35761  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35762  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35763  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 35764  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35765              [chunk_Pi, r_9, h, l_4, h, l_1, v, v]
# ...                                                  ...
# 41490                           [chunk_L, r_9, chunk_Pi]
# 41491                           [chunk_L, r_12, chunk_C]
# 41492                           [chunk_C, r_6, chunk_Pi]
# 41493                           [chunk_C, r_12, chunk_L]
# 41494                           [chunk_Pi, r_7, chunk_C]
# 41495                           [chunk_Pi, r_9, chunk_L]
# 39996  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 39997  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 39998  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 39999  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 40000                  [chunk_8b, r_9, h, l_4, chunk_Pi]
# 40001                           [chunk_C, r_12, chunk_L]
# 40002                           [chunk_L, r_9, chunk_Pi]
# 40003                           [chunk_L, r_12, chunk_C]
# 40004                           [chunk_C, r_6, chunk_Pi]
# 40005                           [chunk_C, r_12, chunk_L]
# 40006                           [chunk_Pi, r_7, chunk_C]
# 40007                           [chunk_Pi, r_9, chunk_L]
# 17196  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 17197  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 17198  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 17199  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 17200                  [chunk_8b, r_9, h, l_4, chunk_Pi]
# 17201                           [chunk_C, r_12, chunk_L]
# 17202                           [chunk_L, r_9, chunk_Pi]
# 17203                           [chunk_L, r_12, chunk_C]
# 17204                           [chunk_C, r_6, chunk_Pi]
# 17205                           [chunk_C, r_12, chunk_L]
# 17206                           [chunk_Pi, r_7, chunk_C]
# 17207                           [chunk_Pi, r_9, chunk_L]
#
#                                     listenerResponseList  \
# 27696  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 27697  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 27698  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 27699  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 27700  [h, l_1, v, v, r_1, h, r_12, r_5, l_4, h, l_1,...
# 27701  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 27702  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 27703  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 27704  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 27705  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 27706  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 27707  [v, r_6, v, l_5, h, r_4, l_0, r_9, h, l_4, h, ...
# 35808  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35809  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35810  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35811  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 35812  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35813  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 35814  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35815  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35816  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35817  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35818  [v, r_6, v, l_5, h, r_4, h, r_7, h, l_1, v, v,...
# 35819  [v, r_6, v, l_5, h, r_4, h, r_9, h, l_4, h, l_...
# 35760  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 35761  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 35762  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 35763      [v, r_6, v, l_9, h, r_4, h, r_7, r_6, r_1, h]
# 35764  [h, l_1, v, v, r_1, h, r_12, h, l_4, h, l_1, v...
# 35765              [chunk_Pi, r_9, h, l_4, h, l_1, v, v]
# ...                                                  ...
# 41490                          [chunk_Pi, r_9, chunk_8b]
# 41491                          [chunk_8, r_12, chunk_8b]
# 41492                          [chunk_8b, r_6, chunk_Pi]
# 41493                           [chunk_C, r_12, chunk_C]
# 41494                           [chunk_C, r_7, chunk_8b]
# 41495                          [chunk_8b, r_9, chunk_Pi]
# 39996  [h, l_4, h, l_1, v, r_12, r_12, h, l_1, v, v, ...
# 39997  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 39998  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, r_3, h,...
# 39999  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 40000                  [chunk_Pi, r_9, h, r_1, chunk_Pi]
# 40001                          [chunk_8, r_12, chunk_8b]
# 40002                          [chunk_8b, r_9, chunk_8b]
# 40003                          [chunk_Pi, r_12, chunk_L]
# 40004                           [chunk_8, r_6, chunk_Pi]
# 40005                          [chunk_L, r_12, chunk_Pi]
# 40006                            [chunk_L, r_7, chunk_8]
# 40007                          [chunk_8b, r_9, chunk_8b]
# 17196  [h, l_4, h, l_1, v, v, r_12, h, l_1, v, v, r_1...
# 17197  [h, l_1, v, v, r_1, h, r_6, v, r_6, v, l_5, h,...
# 17198  [h, l_4, h, l_1, v, v, r_9, v, r_6, v, l_5, h,...
# 17199  [v, r_6, v, l_5, h, r_4, h, r_7, chunk_8b, r_1...
# 17200                  [chunk_8b, r_9, h, l_4, chunk_Pi]
# 17201                         [chunk_Pi, r_12, chunk_8b]
# 17202                           [chunk_8, r_9, chunk_8b]
# 17203                         [chunk_Pi, r_12, chunk_8b]
# 17204                           [chunk_8b, r_0, chunk_C]
# 17205                         [chunk_8b, r_12, chunk_8b]
# 17206                            [chunk_C, r_7, chunk_8]
# 17207                           [chunk_8b, r_9, chunk_L]
#
#                                     speakerUtteranceList  \
# 27696  [place a horizontal block., move to the left b...
# 27697  [place a horizontal block., move to the left b...
# 27698  [place a horizontal block., move to the left b...
# 27699  [place a vertical block., move to the right by...
# 27700  [place a horizontal block., move to the left b...
# 27701  [place a vertical block., move to the right by...
# 27702  [place a horizontal block., move to the left b...
# 27703  [place a horizontal block., move to the left b...
# 27704  [place a horizontal block., move to the left b...
# 27705  [place a horizontal block., move to the left b...
# 27706  [place a vertical block., move to the right by...
# 27707  [place a vertical block., move to the right by...
# 35808  [place a horizontal block., move to the left b...
# 35809  [place a horizontal block., move to the left b...
# 35810  [place a horizontal block., move to the left b...
# 35811  [place a vertical block., move to the right by...
# 35812  [place a horizontal block., move to the left b...
# 35813  [place a vertical block., move to the right by...
# 35814  [place a horizontal block., move to the left b...
# 35815  [place a horizontal block., move to the left b...
# 35816  [place a horizontal block., move to the left b...
# 35817  [place a horizontal block., move to the left b...
# 35818  [place a vertical block., move to the right by...
# 35819  [place a vertical block., move to the right by...
# 35760  [place a horizontal block., move to the left b...
# 35761  [place a horizontal block., move to the left b...
# 35762  [place a horizontal block., move to the left b...
# 35763  [place a vertical block., move to the right by...
# 35764  [place a horizontal block., move to the left b...
# 35765  [bloop, move to the right by 9, place a horizo...
# ...                                                  ...
# 41490             [bleep, move to the right by 9, bleep]
# 41491            [bleep, move to the right by 12, bleep]
# 41492             [bleep, move to the right by 6, bleep]
# 41493            [bleep, move to the right by 12, bleep]
# 41494             [bleep, move to the right by 7, bleep]
# 41495             [bleep, move to the right by 9, bleep]
# 39996  [place a horizontal block., move to the left b...
# 39997  [place a horizontal block., move to the left b...
# 39998  [place a horizontal block., move to the left b...
# 39999  [place a vertical block., move to the right by...
# 40000  [bleep, move to the right by 9, place a horizo...
# 40001            [bleep, move to the right by 12, bleep]
# 40002              [bleep, move to the right by 9, blab]
# 40003             [blab, move to the right by 12, bleep]
# 40004             [bleep, move to the right by 6, bleep]
# 40005            [bleep, move to the right by 12, bleep]
# 40006              [bleep, move to the right by 7, blab]
# 40007              [blab, move to the right by 9, bleep]
# 17196  [place a horizontal block., move to the left b...
# 17197  [place a horizontal block., move to the left b...
# 17198  [place a horizontal block., move to the left b...
# 17199  [place a vertical block., move to the right by...
# 17200  [blah, move to the right by 9, place a horizon...
# 17201             [blah, move to the right by 12, blarp]
# 17202             [blarp, move to the right by 9, bloop]
# 17203            [bloop, move to the right by 12, bloop]
# 17204             [bloop, move to the right by 6, bleep]
# 17205            [bloop, move to the right by 12, bloop]
# 17206              [blah, move to the right by 7, bleep]
# 17207              [bleep, move to the right by 9, blah]
#
#                                    speakerUtteranceWords  \
# 27696  [place a horizontal block., move to the left b...
# 27697  [place a horizontal block., move to the left b...
# 27698  [place a horizontal block., move to the left b...
# 27699  [place a vertical block., move to the right by...
# 27700  [place a horizontal block., move to the left b...
# 27701  [place a vertical block., move to the right by...
# 27702  [place a horizontal block., move to the left b...
# 27703  [place a horizontal block., move to the left b...
# 27704  [place a horizontal block., move to the left b...
# 27705  [place a horizontal block., move to the left b...
# 27706  [place a vertical block., move to the right by...
# 27707  [place a vertical block., move to the right by...
# 35808  [place a horizontal block., move to the left b...
# 35809  [place a horizontal block., move to the left b...
# 35810  [place a horizontal block., move to the left b...
# 35811  [place a vertical block., move to the right by...
# 35812  [place a horizontal block., move to the left b...
# 35813  [place a vertical block., move to the right by...
# 35814  [place a horizontal block., move to the left b...
# 35815  [place a horizontal block., move to the left b...
# 35816  [place a horizontal block., move to the left b...
# 35817  [place a horizontal block., move to the left b...
# 35818  [place a vertical block., move to the right by...
# 35819  [place a vertical block., move to the right by...
# 35760  [place a horizontal block., move to the left b...
# 35761  [place a horizontal block., move to the left b...
# 35762  [place a horizontal block., move to the left b...
# 35763  [place a vertical block., move to the right by...
# 35764  [place a horizontal block., move to the left b...
# 35765  [bloop, move to the right by 9, place a horizo...
# ...                                                  ...
# 41490             [bleep, move to the right by 9, bleep]
# 41491            [bleep, move to the right by 12, bleep]
# 41492             [bleep, move to the right by 6, bleep]
# 41493            [bleep, move to the right by 12, bleep]
# 41494             [bleep, move to the right by 7, bleep]
# 41495             [bleep, move to the right by 9, bleep]
# 39996  [place a horizontal block., move to the left b...
# 39997  [place a horizontal block., move to the left b...
# 39998  [place a horizontal block., move to the left b...
# 39999  [place a vertical block., move to the right by...
# 40000  [bleep, move to the right by 9, place a horizo...
# 40001            [bleep, move to the right by 12, bleep]
# 40002              [bleep, move to the right by 9, blab]
# 40003             [blab, move to the right by 12, bleep]
# 40004             [bleep, move to the right by 6, bleep]
# 40005            [bleep, move to the right by 12, bleep]
# 40006              [bleep, move to the right by 7, blab]
# 40007              [blab, move to the right by 9, bleep]
# 17196  [place a horizontal block., move to the left b...
# 17197  [place a horizontal block., move to the left b...
# 17198  [place a horizontal block., move to the left b...
# 17199  [place a vertical block., move to the right by...
# 17200  [blah, move to the right by 9, place a horizon...
# 17201             [blah, move to the right by 12, blarp]
# 17202             [blarp, move to the right by 9, bloop]
# 17203            [bloop, move to the right by 12, bloop]
# 17204             [bloop, move to the right by 6, bleep]
# 17205            [bloop, move to the right by 12, bloop]
# 17206              [blah, move to the right by 7, bleep]
# 17207              [bleep, move to the right by 9, blah]
#
#                    intended_refs repetition  \
# 27696   [h, h, v, v, v, v, h, h]        1.0
# 27697   [h, h, v, v, h, v, v, h]        1.0
# 27698   [h, v, v, h, v, v, h, h]        1.0
# 27699  [v, v, h, h, chunk_8b, h]        2.0
# 27700   [h, v, v, h, h, h, v, v]        2.0
# 27701   [v, v, h, h, h, h, v, v]        2.0
# 27702   [h, h, v, v, h, v, v, h]        3.0
# 27703   [h, v, v, h, v, v, h, h]        3.0
# 27704   [h, h, v, v, v, v, h, h]        3.0
# 27705   [h, v, v, h, h, h, v, v]        4.0
# 27706   [v, v, h, h, h, v, v, h]        4.0
# 27707   [v, v, h, h, h, h, v, v]        4.0
# 35808   [h, h, v, v, v, v, h, h]        1.0
# 35809   [h, h, v, v, h, v, v, h]        1.0
# 35810   [h, v, v, h, v, v, h, h]        1.0
# 35811  [v, v, h, h, chunk_8b, h]        2.0
# 35812   [h, v, v, h, h, h, v, v]        2.0
# 35813   [v, v, h, h, h, h, v, v]        2.0
# 35814   [h, h, v, v, h, v, v, h]        3.0
# 35815   [h, v, v, h, v, v, h, h]        3.0
# 35816   [h, h, v, v, v, v, h, h]        3.0
# 35817   [h, v, v, h, h, h, v, v]        4.0
# 35818   [v, v, h, h, h, v, v, h]        4.0
# 35819   [v, v, h, h, h, h, v, v]        4.0
# 35760   [h, h, v, v, v, v, h, h]        1.0
# 35761   [h, h, v, v, h, v, v, h]        1.0
# 35762   [h, v, v, h, v, v, h, h]        1.0
# 35763  [v, v, h, h, chunk_8b, h]        2.0
# 35764   [h, v, v, h, h, h, v, v]        2.0
# 35765     [chunk_Pi, h, h, v, v]        2.0
# ...                          ...        ...
# 41490        [chunk_L, chunk_Pi]        3.0
# 41491         [chunk_L, chunk_C]        3.0
# 41492        [chunk_C, chunk_Pi]        3.0
# 41493         [chunk_C, chunk_L]        4.0
# 41494        [chunk_Pi, chunk_C]        4.0
# 41495        [chunk_Pi, chunk_L]        4.0
# 39996   [h, h, v, v, h, v, v, h]        1.0
# 39997   [h, v, v, h, v, v, h, h]        1.0
# 39998   [h, h, v, v, v, v, h, h]        1.0
# 39999  [v, v, h, h, chunk_8b, h]        2.0
# 40000    [chunk_8b, h, chunk_Pi]        2.0
# 40001         [chunk_C, chunk_L]        2.0
# 40002        [chunk_L, chunk_Pi]        3.0
# 40003         [chunk_L, chunk_C]        3.0
# 40004        [chunk_C, chunk_Pi]        3.0
# 40005         [chunk_C, chunk_L]        4.0
# 40006        [chunk_Pi, chunk_C]        4.0
# 40007        [chunk_Pi, chunk_L]        4.0
# 17196   [h, h, v, v, h, v, v, h]        1.0
# 17197   [h, v, v, h, v, v, h, h]        1.0
# 17198   [h, h, v, v, v, v, h, h]        1.0
# 17199  [v, v, h, h, chunk_8b, h]        2.0
# 17200    [chunk_8b, h, chunk_Pi]        2.0
# 17201         [chunk_C, chunk_L]        2.0
# 17202        [chunk_L, chunk_Pi]        3.0
# 17203         [chunk_L, chunk_C]        3.0
# 17204        [chunk_C, chunk_Pi]        3.0
# 17205         [chunk_C, chunk_L]        4.0
# 17206        [chunk_Pi, chunk_C]        4.0
# 17207        [chunk_Pi, chunk_L]        4.0
#
#                               intended_abstraction_level intended_blocks  \
# 27696  [block, block, block, block, block, block, blo...               8
# 27697  [block, block, block, block, block, block, blo...               8
# 27698  [block, block, block, block, block, block, blo...               8
# 27699      [block, block, block, block, subtower, block]               5
# 27700  [block, block, block, block, block, block, blo...               8
# 27701  [block, block, block, block, block, block, blo...               8
# 27702  [block, block, block, block, block, block, blo...               8
# 27703  [block, block, block, block, block, block, blo...               8
# 27704  [block, block, block, block, block, block, blo...               8
# 27705  [block, block, block, block, block, block, blo...               8
# 27706  [block, block, block, block, block, block, blo...               8
# 27707  [block, block, block, block, block, block, blo...               8
# 35808  [block, block, block, block, block, block, blo...               8
# 35809  [block, block, block, block, block, block, blo...               8
# 35810  [block, block, block, block, block, block, blo...               8
# 35811      [block, block, block, block, subtower, block]               5
# 35812  [block, block, block, block, block, block, blo...               8
# 35813  [block, block, block, block, block, block, blo...               8
# 35814  [block, block, block, block, block, block, blo...               8
# 35815  [block, block, block, block, block, block, blo...               8
# 35816  [block, block, block, block, block, block, blo...               8
# 35817  [block, block, block, block, block, block, blo...               8
# 35818  [block, block, block, block, block, block, blo...               8
# 35819  [block, block, block, block, block, block, blo...               8
# 35760  [block, block, block, block, block, block, blo...               8
# 35761  [block, block, block, block, block, block, blo...               8
# 35762  [block, block, block, block, block, block, blo...               8
# 35763      [block, block, block, block, subtower, block]               5
# 35764  [block, block, block, block, block, block, blo...               8
# 35765                [tower, block, block, block, block]               4
# ...                                                  ...             ...
# 41490                                     [tower, tower]               0
# 41491                                     [tower, tower]               0
# 41492                                     [tower, tower]               0
# 41493                                     [tower, tower]               0
# 41494                                     [tower, tower]               0
# 41495                                     [tower, tower]               0
# 39996  [block, block, block, block, block, block, blo...               8
# 39997  [block, block, block, block, block, block, blo...               8
# 39998  [block, block, block, block, block, block, blo...               8
# 39999      [block, block, block, block, subtower, block]               5
# 40000                           [subtower, block, tower]               1
# 40001                                     [tower, tower]               0
# 40002                                     [tower, tower]               0
# 40003                                     [tower, tower]               0
# 40004                                     [tower, tower]               0
# 40005                                     [tower, tower]               0
# 40006                                     [tower, tower]               0
# 40007                                     [tower, tower]               0
# 17196  [block, block, block, block, block, block, blo...               8
# 17197  [block, block, block, block, block, block, blo...               8
# 17198  [block, block, block, block, block, block, blo...               8
# 17199      [block, block, block, block, subtower, block]               5
# 17200                           [subtower, block, tower]               1
# 17201                                     [tower, tower]               0
# 17202                                     [tower, tower]               0
# 17203                                     [tower, tower]               0
# 17204                                     [tower, tower]               0
# 17205                                     [tower, tower]               0
# 17206                                     [tower, tower]               0
# 17207                                     [tower, tower]               0
#
#        intended_subtowers  intended_towers
# 27696                   0                0
# 27697                   0                0
# 27698                   0                0
# 27699                   1                0
# 27700                   0                0
# 27701                   0                0
# 27702                   0                0
# 27703                   0                0
# 27704                   0                0
# 27705                   0                0
# 27706                   0                0
# 27707                   0                0
# 35808                   0                0
# 35809                   0                0
# 35810                   0                0
# 35811                   1                0
# 35812                   0                0
# 35813                   0                0
# 35814                   0                0
# 35815                   0                0
# 35816                   0                0
# 35817                   0                0
# 35818                   0                0
# 35819                   0                0
# 35760                   0                0
# 35761                   0                0
# 35762                   0                0
# 35763                   1                0
# 35764                   0                0
# 35765                   0                1
# ...                   ...              ...
# 41490                   0                2
# 41491                   0                2
# 41492                   0                2
# 41493                   0                2
# 41494                   0                2
# 41495                   0                2
# 39996                   0                0
# 39997                   0                0
# 39998                   0                0
# 39999                   1                0
# 40000                   1                1
# 40001                   0                2
# 40002                   0                2
# 40003                   0                2
# 40004                   0                2
# 40005                   0                2
# 40006                   0                2
# 40007                   0                2
# 17196                   0                0
# 17197                   0                0
# 17198                   0                0
# 17199                   1                0
# 17200                   1                1
# 17201                   0                2
# 17202                   0                2
# 17203                   0                2
# 17204                   0                2
# 17205                   0                2
# 17206                   0                2
# 17207                   0                2
#
# [51744 rows x 21 columns]

# %%
def score_action_response(intended, executed):
    if intended==executed:
        if (intended.startswith('l_') or intended.startswith('r_')):
            return 0
        if (intended=='h') or (intended=='v'):
            return 1
        if (intended=='chunk_Pi') or (intended=='chunk_L') or (intended=='chunk_C'):
            return 4
        if (intended=='chunk_8') or (intended=='chunk_8b'):
            return 3
        if (intended=='chunk_9'):
            return 2
        else:
            print(intended)
    else:
        return 0

# %%
# plus one for every correct block in referring expressions 
df_model['soft_score'] = [sum(list(score_action_response(a,b) for (a,b) in zip(row['intendedSequenceList'], 
                                                                               row['listenerResponseList'])))\
                                                                  for i, row in df_model.iterrows()]

# %%
# soft accuracy
df_model['correct_action'] = [list(a == b for (a,b) in zip(row['intendedSequenceList'], row['listenerResponseList'])) for i, row in df_model.iterrows()]

# %%
df_model['prop_correct_action'] = df_model['correct_action'].apply(np.mean)

# %% [markdown]
# ## Referring expressions

# %%
df_model[df_model.beta.isin([0,0.2,0.4,0.6,0.8,1])]
# Out:
#        chainNum  ppt  iteration  alpha  beta  trialNum  accuracy  \
# 27696         0    1          0      1   0.0         0      True
# 27697         0    1          0      1   0.0         1      True
# 27698         0    1          0      1   0.0         2      True
# 27699         0    1          0      1   0.0         3      True
# 27700         0    1          0      1   0.0         4     False
# 27701         0    1          0      1   0.0         5      True
# 27702         0    1          0      1   0.0         6      True
# 27703         0    1          0      1   0.0         7      True
# 27704         0    1          0      1   0.0         8      True
# 27705         0    1          0      1   0.0         9      True
# 27706         0    1          0      1   0.0        10      True
# 27707         0    1          0      1   0.0        11     False
# 35760        98    1          0      1   0.2         0      True
# 35761        98    1          0      1   0.2         1      True
# 35762        98    1          0      1   0.2         2      True
# 35763        98    1          0      1   0.2         3     False
# 35764        98    1          0      1   0.2         4      True
# 35765        98    1          0      1   0.2         5      True
# 35766        98    1          0      1   0.2         6      True
# 35767        98    1          0      1   0.2         7      True
# 35768        98    1          0      1   0.2         8     False
# 35769        98    1          0      1   0.2         9      True
# 35770        98    1          0      1   0.2        10     False
# 35771        98    1          0      1   0.2        11      True
# 2112        196    1          0      1   0.4         0     False
# 2113        196    1          0      1   0.4         1      True
# 2114        196    1          0      1   0.4         2     False
# 2115        196    1          0      1   0.4         3      True
# 2116        196    1          0      1   0.4         4      True
# 2117        196    1          0      1   0.4         5     False
# ...         ...  ...        ...    ...   ...       ...       ...
# 31362      1959   49          1     64   0.6         6     False
# 31363      1959   49          1     64   0.6         7     False
# 31364      1959   49          1     64   0.6         8     False
# 31365      1959   49          1     64   0.6         9     False
# 31366      1959   49          1     64   0.6        10      True
# 31367      1959   49          1     64   0.6        11     False
# 41484      2057   49          1     64   0.8         0      True
# 41485      2057   49          1     64   0.8         1      True
# 41486      2057   49          1     64   0.8         2      True
# 41487      2057   49          1     64   0.8         3      True
# 41488      2057   49          1     64   0.8         4     False
# 41489      2057   49          1     64   0.8         5     False
# 41490      2057   49          1     64   0.8         6     False
# 41491      2057   49          1     64   0.8         7     False
# 41492      2057   49          1     64   0.8         8     False
# 41493      2057   49          1     64   0.8         9     False
# 41494      2057   49          1     64   0.8        10     False
# 41495      2057   49          1     64   0.8        11     False
# 17196      2155   49          1     64   1.0         0      True
# 17197      2155   49          1     64   1.0         1      True
# 17198      2155   49          1     64   1.0         2      True
# 17199      2155   49          1     64   1.0         3      True
# 17200      2155   49          1     64   1.0         4      True
# 17201      2155   49          1     64   1.0         5     False
# 17202      2155   49          1     64   1.0         6     False
# 17203      2155   49          1     64   1.0         7     False
# 17204      2155   49          1     64   1.0         8     False
# 17205      2155   49          1     64   1.0         9     False
# 17206      2155   49          1     64   1.0        10     False
# 17207      2155   49          1     64   1.0        11     False
#
#        descriptionLength                         intendedSequence  \
# 27696                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 27697                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 27698                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 27699                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 27700                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 27701                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 27702                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 27703                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 27704                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 27705                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 27706                 14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 27707                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 35760                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35761                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35762                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35763                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 35764                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 35765                  8             chunk_Pi r_9 h l_4 h l_1 v v
# 35766                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 35767                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 35768                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 35769                 13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 35770                  8             chunk_Pi r_7 h l_1 v v r_1 h
# 35771                 14  v r_6 v l_5 h r_4 h r_9 h l_4 h l_1 v v
# 2112                  14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 2113                  13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 2114                  14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 2115                  14  v r_6 v l_5 h r_4 h r_7 h l_1 v v r_1 h
# 2116                  13     h l_1 v v r_1 h r_12 h l_4 h l_1 v v
# 2117                   9          v r_6 v l_5 h r_4 h r_9 chunk_L
# ...                  ...                                      ...
# 31362                  3                     chunk_L r_9 chunk_Pi
# 31363                  3                     chunk_L r_12 chunk_C
# 31364                  3                     chunk_C r_6 chunk_Pi
# 31365                  3                     chunk_C r_12 chunk_L
# 31366                  3                     chunk_Pi r_7 chunk_C
# 31367                  3                     chunk_Pi r_9 chunk_L
# 41484                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 41485                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 41486                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 41487                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 41488                  5              chunk_8b r_9 h l_4 chunk_Pi
# 41489                  3                     chunk_C r_12 chunk_L
# 41490                  3                     chunk_L r_9 chunk_Pi
# 41491                  3                     chunk_L r_12 chunk_C
# 41492                  3                     chunk_C r_6 chunk_Pi
# 41493                  3                     chunk_C r_12 chunk_L
# 41494                  3                     chunk_Pi r_7 chunk_C
# 41495                  3                     chunk_Pi r_9 chunk_L
# 17196                 13     h l_4 h l_1 v v r_12 h l_1 v v r_1 h
# 17197                 14  h l_1 v v r_1 h r_6 v r_6 v l_5 h r_4 h
# 17198                 14  h l_4 h l_1 v v r_9 v r_6 v l_5 h r_4 h
# 17199                 11   v r_6 v l_5 h r_4 h r_7 chunk_8b r_1 h
# 17200                  5              chunk_8b r_9 h l_4 chunk_Pi
# 17201                  3                     chunk_C r_12 chunk_L
# 17202                  3                     chunk_L r_9 chunk_Pi
# 17203                  3                     chunk_L r_12 chunk_C
# 17204                  3                     chunk_C r_6 chunk_Pi
# 17205                  3                     chunk_C r_12 chunk_L
# 17206                  3                     chunk_Pi r_7 chunk_C
# 17207                  3                     chunk_Pi r_9 chunk_L
#
#                                         speakerUtterance  ...  \
# 27696  place a horizontal block.~~~move to the left b...  ...
# 27697  place a horizontal block.~~~move to the left b...  ...
# 27698  place a horizontal block.~~~move to the left b...  ...
# 27699  place a vertical block.~~~move to the right by...  ...
# 27700  place a horizontal block.~~~move to the left b...  ...
# 27701  place a vertical block.~~~move to the right by...  ...
# 27702  place a horizontal block.~~~move to the left b...  ...
# 27703  place a horizontal block.~~~move to the left b...  ...
# 27704  place a horizontal block.~~~move to the left b...  ...
# 27705  place a horizontal block.~~~move to the left b...  ...
# 27706  place a vertical block.~~~move to the right by...  ...
# 27707  place a vertical block.~~~move to the right by...  ...
# 35760  place a horizontal block.~~~move to the left b...  ...
# 35761  place a horizontal block.~~~move to the left b...  ...
# 35762  place a horizontal block.~~~move to the left b...  ...
# 35763  place a vertical block.~~~move to the right by...  ...
# 35764  place a horizontal block.~~~move to the left b...  ...
# 35765  bloop~~~move to the right by 9~~~place a horiz...  ...
# 35766  place a horizontal block.~~~move to the left b...  ...
# 35767  place a horizontal block.~~~move to the left b...  ...
# 35768  place a horizontal block.~~~move to the left b...  ...
# 35769  place a horizontal block.~~~move to the left b...  ...
# 35770  bloop~~~move to the right by 7~~~place a horiz...  ...
# 35771  place a vertical block.~~~move to the right by...  ...
# 2112   place a horizontal block.~~~move to the left b...  ...
# 2113   place a horizontal block.~~~move to the left b...  ...
# 2114   place a horizontal block.~~~move to the left b...  ...
# 2115   place a vertical block.~~~move to the right by...  ...
# 2116   place a horizontal block.~~~move to the left b...  ...
# 2117   place a vertical block.~~~move to the right by...  ...
# ...                                                  ...  ...
# 31362             bloop~~~move to the right by 9~~~blarp  ...
# 31363             bloop~~~move to the right by 12~~~blab  ...
# 31364               blab~~~move to the right by 6~~~blah  ...
# 31365             blab~~~move to the right by 12~~~bloop  ...
# 31366              blah~~~move to the right by 7~~~bloop  ...
# 31367              blah~~~move to the right by 9~~~bloop  ...
# 41484  place a horizontal block.~~~move to the left b...  ...
# 41485  place a horizontal block.~~~move to the left b...  ...
# 41486  place a horizontal block.~~~move to the left b...  ...
# 41487  place a vertical block.~~~move to the right by...  ...
# 41488  bleep~~~move to the right by 9~~~place a horiz...  ...
# 41489            bleep~~~move to the right by 12~~~bleep  ...
# 41490             bleep~~~move to the right by 9~~~bleep  ...
# 41491            bleep~~~move to the right by 12~~~bleep  ...
# 41492             bleep~~~move to the right by 6~~~bleep  ...
# 41493            bleep~~~move to the right by 12~~~bleep  ...
# 41494             bleep~~~move to the right by 7~~~bleep  ...
# 41495             bleep~~~move to the right by 9~~~bleep  ...
# 17196  place a horizontal block.~~~move to the left b...  ...
# 17197  place a horizontal block.~~~move to the left b...  ...
# 17198  place a horizontal block.~~~move to the left b...  ...
# 17199  place a vertical block.~~~move to the right by...  ...
# 17200  blah~~~move to the right by 9~~~place a horizo...  ...
# 17201             blah~~~move to the right by 12~~~blarp  ...
# 17202             blarp~~~move to the right by 9~~~bloop  ...
# 17203            bloop~~~move to the right by 12~~~bloop  ...
# 17204             bloop~~~move to the right by 6~~~bleep  ...
# 17205            bloop~~~move to the right by 12~~~bloop  ...
# 17206              blah~~~move to the right by 7~~~bleep  ...
# 17207              bleep~~~move to the right by 9~~~blah  ...
#
#                                    speakerUtteranceWords  \
# 27696  [place a horizontal block., move to the left b...
# 27697  [place a horizontal block., move to the left b...
# 27698  [place a horizontal block., move to the left b...
# 27699  [place a vertical block., move to the right by...
# 27700  [place a horizontal block., move to the left b...
# 27701  [place a vertical block., move to the right by...
# 27702  [place a horizontal block., move to the left b...
# 27703  [place a horizontal block., move to the left b...
# 27704  [place a horizontal block., move to the left b...
# 27705  [place a horizontal block., move to the left b...
# 27706  [place a vertical block., move to the right by...
# 27707  [place a vertical block., move to the right by...
# 35760  [place a horizontal block., move to the left b...
# 35761  [place a horizontal block., move to the left b...
# 35762  [place a horizontal block., move to the left b...
# 35763  [place a vertical block., move to the right by...
# 35764  [place a horizontal block., move to the left b...
# 35765  [bloop, move to the right by 9, place a horizo...
# 35766  [place a horizontal block., move to the left b...
# 35767  [place a horizontal block., move to the left b...
# 35768  [place a horizontal block., move to the left b...
# 35769  [place a horizontal block., move to the left b...
# 35770  [bloop, move to the right by 7, place a horizo...
# 35771  [place a vertical block., move to the right by...
# 2112   [place a horizontal block., move to the left b...
# 2113   [place a horizontal block., move to the left b...
# 2114   [place a horizontal block., move to the left b...
# 2115   [place a vertical block., move to the right by...
# 2116   [place a horizontal block., move to the left b...
# 2117   [place a vertical block., move to the right by...
# ...                                                  ...
# 31362             [bloop, move to the right by 9, blarp]
# 31363             [bloop, move to the right by 12, blab]
# 31364               [blab, move to the right by 6, blah]
# 31365             [blab, move to the right by 12, bloop]
# 31366              [blah, move to the right by 7, bloop]
# 31367              [blah, move to the right by 9, bloop]
# 41484  [place a horizontal block., move to the left b...
# 41485  [place a horizontal block., move to the left b...
# 41486  [place a horizontal block., move to the left b...
# 41487  [place a vertical block., move to the right by...
# 41488  [bleep, move to the right by 9, place a horizo...
# 41489            [bleep, move to the right by 12, bleep]
# 41490             [bleep, move to the right by 9, bleep]
# 41491            [bleep, move to the right by 12, bleep]
# 41492             [bleep, move to the right by 6, bleep]
# 41493            [bleep, move to the right by 12, bleep]
# 41494             [bleep, move to the right by 7, bleep]
# 41495             [bleep, move to the right by 9, bleep]
# 17196  [place a horizontal block., move to the left b...
# 17197  [place a horizontal block., move to the left b...
# 17198  [place a horizontal block., move to the left b...
# 17199  [place a vertical block., move to the right by...
# 17200  [blah, move to the right by 9, place a horizon...
# 17201             [blah, move to the right by 12, blarp]
# 17202             [blarp, move to the right by 9, bloop]
# 17203            [bloop, move to the right by 12, bloop]
# 17204             [bloop, move to the right by 6, bleep]
# 17205            [bloop, move to the right by 12, bloop]
# 17206              [blah, move to the right by 7, bleep]
# 17207              [bleep, move to the right by 9, blah]
#
#                    intended_refs repetition  \
# 27696   [h, h, v, v, v, v, h, h]        1.0
# 27697   [h, h, v, v, h, v, v, h]        1.0
# 27698   [h, v, v, h, v, v, h, h]        1.0
# 27699  [v, v, h, h, chunk_8b, h]        2.0
# 27700   [h, v, v, h, h, h, v, v]        2.0
# 27701   [v, v, h, h, h, h, v, v]        2.0
# 27702   [h, h, v, v, h, v, v, h]        3.0
# 27703   [h, v, v, h, v, v, h, h]        3.0
# 27704   [h, h, v, v, v, v, h, h]        3.0
# 27705   [h, v, v, h, h, h, v, v]        4.0
# 27706   [v, v, h, h, h, v, v, h]        4.0
# 27707   [v, v, h, h, h, h, v, v]        4.0
# 35760   [h, h, v, v, v, v, h, h]        1.0
# 35761   [h, h, v, v, h, v, v, h]        1.0
# 35762   [h, v, v, h, v, v, h, h]        1.0
# 35763  [v, v, h, h, chunk_8b, h]        2.0
# 35764   [h, v, v, h, h, h, v, v]        2.0
# 35765     [chunk_Pi, h, h, v, v]        2.0
# 35766   [h, h, v, v, h, v, v, h]        3.0
# 35767   [h, v, v, h, v, v, h, h]        3.0
# 35768   [h, h, v, v, v, v, h, h]        3.0
# 35769   [h, v, v, h, h, h, v, v]        4.0
# 35770     [chunk_Pi, h, v, v, h]        4.0
# 35771   [v, v, h, h, h, h, v, v]        4.0
# 2112    [h, h, v, v, v, v, h, h]        1.0
# 2113    [h, h, v, v, h, v, v, h]        1.0
# 2114    [h, v, v, h, v, v, h, h]        1.0
# 2115    [v, v, h, h, h, v, v, h]        2.0
# 2116    [h, v, v, h, h, h, v, v]        2.0
# 2117       [v, v, h, h, chunk_L]        2.0
# ...                          ...        ...
# 31362        [chunk_L, chunk_Pi]        3.0
# 31363         [chunk_L, chunk_C]        3.0
# 31364        [chunk_C, chunk_Pi]        3.0
# 31365         [chunk_C, chunk_L]        4.0
# 31366        [chunk_Pi, chunk_C]        4.0
# 31367        [chunk_Pi, chunk_L]        4.0
# 41484   [h, h, v, v, h, v, v, h]        1.0
# 41485   [h, v, v, h, v, v, h, h]        1.0
# 41486   [h, h, v, v, v, v, h, h]        1.0
# 41487  [v, v, h, h, chunk_8b, h]        2.0
# 41488    [chunk_8b, h, chunk_Pi]        2.0
# 41489         [chunk_C, chunk_L]        2.0
# 41490        [chunk_L, chunk_Pi]        3.0
# 41491         [chunk_L, chunk_C]        3.0
# 41492        [chunk_C, chunk_Pi]        3.0
# 41493         [chunk_C, chunk_L]        4.0
# 41494        [chunk_Pi, chunk_C]        4.0
# 41495        [chunk_Pi, chunk_L]        4.0
# 17196   [h, h, v, v, h, v, v, h]        1.0
# 17197   [h, v, v, h, v, v, h, h]        1.0
# 17198   [h, h, v, v, v, v, h, h]        1.0
# 17199  [v, v, h, h, chunk_8b, h]        2.0
# 17200    [chunk_8b, h, chunk_Pi]        2.0
# 17201         [chunk_C, chunk_L]        2.0
# 17202        [chunk_L, chunk_Pi]        3.0
# 17203         [chunk_L, chunk_C]        3.0
# 17204        [chunk_C, chunk_Pi]        3.0
# 17205         [chunk_C, chunk_L]        4.0
# 17206        [chunk_Pi, chunk_C]        4.0
# 17207        [chunk_Pi, chunk_L]        4.0
#
#                               intended_abstraction_level intended_blocks  \
# 27696  [block, block, block, block, block, block, blo...               8
# 27697  [block, block, block, block, block, block, blo...               8
# 27698  [block, block, block, block, block, block, blo...               8
# 27699      [block, block, block, block, subtower, block]               5
# 27700  [block, block, block, block, block, block, blo...               8
# 27701  [block, block, block, block, block, block, blo...               8
# 27702  [block, block, block, block, block, block, blo...               8
# 27703  [block, block, block, block, block, block, blo...               8
# 27704  [block, block, block, block, block, block, blo...               8
# 27705  [block, block, block, block, block, block, blo...               8
# 27706  [block, block, block, block, block, block, blo...               8
# 27707  [block, block, block, block, block, block, blo...               8
# 35760  [block, block, block, block, block, block, blo...               8
# 35761  [block, block, block, block, block, block, blo...               8
# 35762  [block, block, block, block, block, block, blo...               8
# 35763      [block, block, block, block, subtower, block]               5
# 35764  [block, block, block, block, block, block, blo...               8
# 35765                [tower, block, block, block, block]               4
# 35766  [block, block, block, block, block, block, blo...               8
# 35767  [block, block, block, block, block, block, blo...               8
# 35768  [block, block, block, block, block, block, blo...               8
# 35769  [block, block, block, block, block, block, blo...               8
# 35770                [tower, block, block, block, block]               4
# 35771  [block, block, block, block, block, block, blo...               8
# 2112   [block, block, block, block, block, block, blo...               8
# 2113   [block, block, block, block, block, block, blo...               8
# 2114   [block, block, block, block, block, block, blo...               8
# 2115   [block, block, block, block, block, block, blo...               8
# 2116   [block, block, block, block, block, block, blo...               8
# 2117                 [block, block, block, block, tower]               4
# ...                                                  ...             ...
# 31362                                     [tower, tower]               0
# 31363                                     [tower, tower]               0
# 31364                                     [tower, tower]               0
# 31365                                     [tower, tower]               0
# 31366                                     [tower, tower]               0
# 31367                                     [tower, tower]               0
# 41484  [block, block, block, block, block, block, blo...               8
# 41485  [block, block, block, block, block, block, blo...               8
# 41486  [block, block, block, block, block, block, blo...               8
# 41487      [block, block, block, block, subtower, block]               5
# 41488                           [subtower, block, tower]               1
# 41489                                     [tower, tower]               0
# 41490                                     [tower, tower]               0
# 41491                                     [tower, tower]               0
# 41492                                     [tower, tower]               0
# 41493                                     [tower, tower]               0
# 41494                                     [tower, tower]               0
# 41495                                     [tower, tower]               0
# 17196  [block, block, block, block, block, block, blo...               8
# 17197  [block, block, block, block, block, block, blo...               8
# 17198  [block, block, block, block, block, block, blo...               8
# 17199      [block, block, block, block, subtower, block]               5
# 17200                           [subtower, block, tower]               1
# 17201                                     [tower, tower]               0
# 17202                                     [tower, tower]               0
# 17203                                     [tower, tower]               0
# 17204                                     [tower, tower]               0
# 17205                                     [tower, tower]               0
# 17206                                     [tower, tower]               0
# 17207                                     [tower, tower]               0
#
#       intended_subtowers  intended_towers soft_score  \
# 27696                  0                0          8
# 27697                  0                0          8
# 27698                  0                0          8
# 27699                  1                0          8
# 27700                  0                0          7
# 27701                  0                0          8
# 27702                  0                0          8
# 27703                  0                0          8
# 27704                  0                0          8
# 27705                  0                0          8
# 27706                  0                0          8
# 27707                  0                0          7
# 35760                  0                0          8
# 35761                  0                0          8
# 35762                  0                0          8
# 35763                  1                0          5
# 35764                  0                0          8
# 35765                  0                1          8
# 35766                  0                0          8
# 35767                  0                0          8
# 35768                  0                0          8
# 35769                  0                0          8
# 35770                  0                1          7
# 35771                  0                0          8
# 2112                   0                0          7
# 2113                   0                0          8
# 2114                   0                0          7
# 2115                   0                0          8
# 2116                   0                0          8
# 2117                   0                1          4
# ...                  ...              ...        ...
# 31362                  0                2          4
# 31363                  0                2          4
# 31364                  0                2          0
# 31365                  0                2          0
# 31366                  0                2          8
# 31367                  0                2          0
# 41484                  0                0          8
# 41485                  0                0          8
# 41486                  0                0          8
# 41487                  1                0          8
# 41488                  1                1          1
# 41489                  0                2          0
# 41490                  0                2          0
# 41491                  0                2          0
# 41492                  0                2          4
# 41493                  0                2          4
# 41494                  0                2          0
# 41495                  0                2          0
# 17196                  0                0          8
# 17197                  0                0          8
# 17198                  0                0          8
# 17199                  1                0          8
# 17200                  1                1          8
# 17201                  0                2          0
# 17202                  0                2          0
# 17203                  0                2          0
# 17204                  0                2          0
# 17205                  0                2          0
# 17206                  0                2          0
# 17207                  0                2          4
#
#                                           correct_action  prop_correct_action
# 27696  [True, True, True, True, True, True, True, Tru...             1.000000
# 27697  [True, True, True, True, True, True, True, Tru...             1.000000
# 27698  [True, True, True, True, True, True, True, Tru...             1.000000
# 27699  [True, True, True, True, True, True, True, Tru...             1.000000
# 27700  [True, True, True, True, True, True, True, Fal...             0.923077
# 27701  [True, True, True, True, True, True, True, Tru...             1.000000
# 27702  [True, True, True, True, True, True, True, Tru...             1.000000
# 27703  [True, True, True, True, True, True, True, Tru...             1.000000
# 27704  [True, True, True, True, True, True, True, Tru...             1.000000
# 27705  [True, True, True, True, True, True, True, Tru...             1.000000
# 27706  [True, True, True, True, True, True, True, Tru...             1.000000
# 27707  [True, True, True, True, True, True, False, Tr...             0.928571
# 35760  [True, True, True, True, True, True, True, Tru...             1.000000
# 35761  [True, True, True, True, True, True, True, Tru...             1.000000
# 35762  [True, True, True, True, True, True, True, Tru...             1.000000
# 35763  [True, True, True, False, True, True, True, Tr...             0.818182
# 35764  [True, True, True, True, True, True, True, Tru...             1.000000
# 35765   [True, True, True, True, True, True, True, True]             1.000000
# 35766  [True, True, True, True, True, True, True, Tru...             1.000000
# 35767  [True, True, True, True, True, True, True, Tru...             1.000000
# 35768  [True, True, True, True, True, True, True, Tru...             0.928571
# 35769  [True, True, True, True, True, True, True, Tru...             1.000000
# 35770  [True, True, True, True, True, True, True, False]             0.875000
# 35771  [True, True, True, True, True, True, True, Tru...             1.000000
# 2112   [True, True, True, True, True, True, True, Tru...             0.928571
# 2113   [True, True, True, True, True, True, True, Tru...             1.000000
# 2114   [False, True, True, True, True, True, True, Tr...             0.928571
# 2115   [True, True, True, True, True, True, True, Tru...             1.000000
# 2116   [True, True, True, True, True, True, True, Tru...             1.000000
# 2117   [True, True, True, True, True, True, True, Tru...             0.888889
# ...                                                  ...                  ...
# 31362                                [True, True, False]             0.666667
# 31363                                [False, True, True]             0.666667
# 31364                               [False, True, False]             0.333333
# 31365                               [False, True, False]             0.333333
# 31366                                 [True, True, True]             1.000000
# 31367                               [False, True, False]             0.333333
# 41484  [True, True, True, True, True, True, True, Tru...             1.000000
# 41485  [True, True, True, True, True, True, True, Tru...             1.000000
# 41486  [True, True, True, True, True, True, True, Tru...             1.000000
# 41487  [True, True, True, True, True, True, True, Tru...             1.000000
# 41488                   [False, True, True, True, False]             0.600000
# 41489                               [False, True, False]             0.333333
# 41490                               [False, True, False]             0.333333
# 41491                               [False, True, False]             0.333333
# 41492                                [False, True, True]             0.666667
# 41493                                [True, True, False]             0.666667
# 41494                               [False, True, False]             0.333333
# 41495                               [False, True, False]             0.333333
# 17196  [True, True, True, True, True, True, True, Tru...             1.000000
# 17197  [True, True, True, True, True, True, True, Tru...             1.000000
# 17198  [True, True, True, True, True, True, True, Tru...             1.000000
# 17199  [True, True, True, True, True, True, True, Tru...             1.000000
# 17200                     [True, True, True, True, True]             1.000000
# 17201                               [False, True, False]             0.333333
# 17202                               [False, True, False]             0.333333
# 17203                               [False, True, False]             0.333333
# 17204                              [False, False, False]             0.000000
# 17205                               [False, True, False]             0.333333
# 17206                               [False, True, False]             0.333333
# 17207                                [False, True, True]             0.666667
#
# [28224 rows x 24 columns]

# %%
black = sns.light_palette("#000000", reverse=False, as_cmap=True)
red = sns.light_palette("#FF0000", reverse=False, as_cmap=True)
green = sns.light_palette("#008000", reverse=False, as_cmap=True)

# %%
fig = plt.figure(figsize=(6,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 3})
sns.lineplot(data=df_model, x='repetition', y='intended_blocks', hue='beta', palette=black)
sns.lineplot(data=df_model, x='repetition', y='intended_subtowers', hue='beta', palette=red)
g = sns.lineplot(data=df_model, x='repetition', y='intended_towers', hue='beta', palette=green)
g.legend().remove()
g.set(xlim=(0.8,4.2))
g.set(xticks=[1,2,3,4])
g.set(xticklabels=['1','2','3','4'])
g.set_yticklabels([str(int(y)) for y in g.get_yticks()], size = 25)
g.set_xticklabels([str(int(x)) for x in g.get_xticks()], size = 25)
g.set(ylabel='')
g.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
df_model_avg = df_model.groupby(['ppt','alpha','beta','repetition']).mean().reset_index()

# %%
# revised plot

subset = df_model_avg[df_model_avg.beta <= 0.5]

fig = plt.figure(figsize=(6,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 3})
sns.lineplot(data=subset, x='repetition', y='intended_blocks', hue='beta', palette=black)
sns.lineplot(data=subset, x='repetition', y='intended_subtowers', hue='beta', palette=red)
g = sns.lineplot(data=subset, x='repetition', y='intended_towers', hue='beta', palette=green)
g.legend().remove()
g.set(xlim=(0.8,4.2))
g.set(xticks=[1,2,3,4])
g.set(xticklabels=['1','2','3','4'])
g.set_yticklabels([str(int(y)) for y in g.get_yticks()], size = 25)
g.set_xticklabels([str(int(x)) for x in g.get_xticks()], size = 25)
g.set(ylabel='')
g.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
#fig.savefig('../../figures/cogsci2021_model_expressions_all_seqs.pdf', transparent=False, bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'soft_score')
plt.legend(bbox_to_anchor=(1.04, 1))

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'repetition', 'intended_blocks')
# g.map(sns.lineplot, 'trialNum', 'intended_subtowers')
g.map(sns.lineplot, 'repetition', 'intended_towers')

# %%
#fig.savefig('../../figures/cogsci2021_model_expressions.pdf', transparent=False, bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Accuracy

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='accuracy', x='trialNum', hue='alpha')

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='accuracy', x='trialNum', hue='beta')

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'accuracy')
plt.legend(bbox_to_anchor=(1.04, 1))

# %%
fig = plt.figure(figsize=(12,10))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='beta', col_wrap=5, hue='alpha')
g.map(sns.lineplot, 'trialNum', 'accuracy')

# %% [markdown]
# ## Number of instructions

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('poster')
sns.set_style('whitegrid', {'legend':False})
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
sns.lineplot(data=df_model, y='descriptionLength', x='trialNum', hue='alpha')

# %%
fig = plt.figure(figsize=(20,8))
sns.set_context('poster')
sns.set_style('whitegrid')
sns.set(style="ticks", rc={"lines.linewidth": 1.5})
g = sns.FacetGrid(df_model, col='alpha', col_wrap=8, hue='beta')
g.map(sns.lineplot, 'trialNum', 'descriptionLength')
