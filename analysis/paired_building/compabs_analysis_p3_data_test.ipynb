# %% [markdown]
# ## Notebook for testing data for pilot 3
#
# Pilot 3 added more checks for engagement early in the experiment.
# Iteration names:
# 'pre-pilot3':

# %%
import os
import sys
import urllib, io
os.getcwd()
sys.path.append("..")
sys.path.append("../utils")
sys.path.append("../analysis/utils")


import numpy as np
import scipy.stats as stats
import pandas as pd

import pymongo as pm
from collections import Counter
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

import drawing_utils as drawing
import importlib
import scoring

# %%
## directory & file hierarchy
proj_dir = os.path.abspath('..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir =  os.path.abspath('.')
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
json_dir = os.path.join(results_dir,'json')
exp_dir = os.path.abspath(os.path.join(proj_dir,'behavioral_experiments'))
png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %%
# set vars 
auth = pd.read_csv(os.path.join(analysis_dir,'auth.txt'), header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org'

# have to fix this to be able to analyze from local
import pymongo as pm
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['compositional-abstractions']
coll = db['two-towers']

# which iteration name should we use?
iterationName = 'pilot3'

## look up number of trials (including paired-practice)
numTrials = 13

# %% [markdown]
# ### construct tidy dataframe with game data

# %% [markdown]
# ### establish connection to mongo
# First thing you need to do is to establish an ssh tunnel (aka remote port forwarding) to the server, so that requests to the mongodb can be made "as if" the mongodb server is running on your local computer. Run this from the command line before you begin data analysis if you plan to fetch data from mongo:
#
# `ssh -fNL 27017:127.0.0.1:27017 USERNAME@cogtoolslab.org`

# %% [markdown]
# #### Pass in list of iterations, returns list of total games and completed games for each

# %%
## get list of all gameIDs in database
#iterationList = ['livetest0','pilot0','pilot2']

iterationList = ['pilot3']

for iteration in iterationList:
    #get total games
    total_games = coll.find({'iterationName':iteration}).distinct('gameid')
    print('There are {} total games in iteration: {}.'.format(len(total_games), iteration))

    ## get list of complete gameIDs
    gameIDs = coll.find({'iterationName':iteration}).distinct('gameid')
    complete_games = [g for g in gameIDs if len(coll.find({'gameid':g}).distinct('trialNum')) == numTrials]
    print('There are {} complete games in iteration: {}.'.format(len(complete_games), iteration))
# Out:
# There are 0 total games in iteration: pilot3.
# There are 0 complete games in iteration: pilot3.

# %%
broken_games = []
complete_games = [g for g in complete_games if g not in broken_games]

def construct_tidy_dataframe(eventType = 'chatMessage', 
                             complete_games = [],
                             iterationName = 'pilot1',
                             remove_workerID = True):
    '''
    input: list of complete games and name of event Type
    '''
    event2name = {'chatMessage':'chat', 'block':'block', 'endTrial':'trial', 'exitSurvey':'exit'}
    L = pd.DataFrame()
    for g, this_gameID in enumerate(complete_games):
        print('Analyzing game {} | {} of {}'.format(this_gameID, g+1, len(complete_games)))
        clear_output(wait=True) 

        ### extract records 
        #loop over iteration names??
        X = coll.find({ '$and': [{'iterationName':iterationName}, 
#                                  {"$or":[{'iterationName':'Exp2Pilot3'},
#                                  {'iterationName':'Exp2Pilot3_batch2'}]}
                                 {'gameid': this_gameID}, {'eventType': eventType}]}).sort('time') 
        
        li = list(X)        
        _L = pd.DataFrame(li)  

        ## concat with previous game's dataframe
        if L.shape[0]==0:
            L = _L
        else: 
            L = pd.concat([L,_L], axis=0)     

    ## postprocessing
    if remove_workerID and 'workerId' in L.columns:
        L = L.drop('workerId',axis=1)

    ## save out group dataframe to csv dir
    out_path = os.path.join(csv_dir,'compabs_{}_{}.csv'.format(event2name[eventType],iterationName))
    print('Saving dataframe out to CSV dir at path: {}'.format(out_path))    
    L.to_csv(out_path)             

    return L

# %%
## construct dataframe for each datatype
dataTypes = coll.distinct('eventType')
for thisDataType in dataTypes:
    X = construct_tidy_dataframe(eventType=thisDataType, complete_games=complete_games, iterationName=iterationName)
# Out:
# Saving dataframe out to CSV dir at path: /Users/will/compositional-abstractions/results/csv/compabs_exit_pre-pilot3.csv

# %% [markdown]
# ## Full DF from DB

# %%
query = coll.find({'iterationName':'pilot3'})

df_full = pd.DataFrame(list(query))
df_full
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
## How many records?
coll.estimated_document_count()
# Out:
# 6419

# %%
df_full[df_full.iterationName=='pilot3']
# Out:
# Empty DataFrame
# Columns: [_id, iterationName, gameid, time, workerId, assignmentId, leftTarget, rightTarget, trialNum, turnNum, repNum, content, timeElapsedInTurn, timeElapsedInTrial, eventType, x, y, width, height, color, block, blockNum, discreteWorld, trialStartTime, turnStartTime, score, gameID, nativeEnglish, isHuman, confused, comments, strategy, role, totalLength, cumulativeScore, cumulativeBonus, trialScore, workerID, individualPracticeAttempts]
# Index: []
#
# [0 rows x 39 columns]

# %% [markdown]
# #### check outcome for specific workerID
# Must pass in workerID and corresponding iteration

# %%
#set worker ID
workerID = 'testsubject003'

#get GameID (not all info available at workerID level (e.g. bonus))
gameID = df_full[df_full['workerId'] == workerID]['gameid'].unique()[0]

#check iteration name
df_game = df_full[(df_full['iterationName'] == iterationName) &
                            (df_full['gameid'] == gameID)]
#get workerIds
print('workerIDS:',df_game['workerId'].unique())
#get bonus for gameID ([air of workerIDs])
print("Bonus:",np.nanmax(df_game['cumulativeBonus']))
# Out:
# workerIDS: ['testsubject003' 'testsubject002']
# Bonus: 0.0

# %%
#see full history for single worker
df_test = df_full[(df_full['iterationName'] == iterationName)&
                           (df_full['workerId'] == workerID)]
df_test.content.unique()
# Out:
# array(['sergaerg', nan, 'aerr'], dtype=object)

# %%
df_full['workerId'].unique()
# Out:
# array(['A1MMCS8S8CTWKU', '', 'A4SSYO0HDVD4E', 'undefined',
#        'A22ZZCICZDCSTY', 'A52FUUEDGSZT9', 'A3D2U4QF7821ZW',
#        'A2S64AUN7JI7ZS', 'A1VR1XQEQQXYUE', 'A2XK59FYAFO9EX',
#        'A1U43WUOJQBK5T', 'A1ZF2GZ2ZRV8OY', 'AD66HP7KFSKJG',
#        'A1BOIDKD33QSDK', 'A15J42M6EC7Y1K', 'A8028AFBBS29G',
#        'A272X64FOZFYLB', 'A3QDEUEUOX24NB', 'A3OVBNOFPMCDAS',
#        'A2ZAOMB6O3ACAV', 'ALYR5CI2SM2JC', 'AH00EJ6PK1H3A',
#        'A3DUL880Y08G95', 'A2Y7RA3JIQXV6M', 'A2GV9WSNSPX53',
#        'A2J18K5IUQ2K4G', 'A3TBR9GIXU42DM', 'A12XVSIL669PVI',
#        'A2QNVAMUHLUVMU', 'A25D8MUZP7CQEY', 'A1ATL3G98SFW4V',
#        'A3ERKH1ZX3VH0Z', 'A8KX1HFH8NE2Q', 'A2TFKXM3RYT39Y',
#        'A1CY7IOJ9YH136', 'ACWVHNV57A8IJ', 'A1O8D22H0D03W1',
#        'AP9WIQ4P78XLH', 'A2WDF40FA670T9', 'A38FIMIHKIJYDN',
#        'A1UEX245I12ZH7', 'A37XBH865833FE', 'AT6LDQNLKTUSE',
#        'A1V2H0UF94ATWY', 'AU75DIKTVX5GP', 'ABNH026RZU28C',
#        'A4LFXI796SAOA', 'AO6YL3KHP84EX', 'A258ZJM0HU1OR3',
#        'AVBRJBJONL47I', 'A12FTSX85NQ8N9', 'A7OZPNXIVO1FX',
#        'A2Y0WNHMT4PZ4C', 'A1ROEDVMTO9Y3X', 'A1969Q0R4Y0E3J',
#        'A3D2GO0IFRFN6R', 'A2PXJTMWGUE5DC', 'A21JE325072629',
#        'A3FAF93BMDJLAL', 'A1OM5NWYYYJKQW', 'AJ4T7PTRYNSUW',
#        'A230VUDYOCRZ4N', 'A2TXZVXQU5FQZ9', 'A2YAYHZYI7M3HD',
#        'A3S2R1NK6HZ9KP', 'A10VQA1XJOOKBS', 'A30KYQGABO7JER',
#        'A2NR9EVYW0LZPN', 'A2NMTMGYVG4IHJ', 'A3URO83ST78FF5',
#        'A12UQ66L9I947W', 'A13G04IFRR6VNW', 'A2PM9J8MEN5BHH',
#        'A3N0QZ9ZKUCTCQ', 'AT3ZTDZVK77F9', 'A37EV8RZ82WT8E',
#        'A2FOUSWQDYHIE0', 'A3LRIIVTVKSJU3', 'A37R0JYAB3QEX9',
#        'A3K9GTQBOI7O5A', 'A29V93KHOIFJCZ', 'A3U505ZZEA876X',
#        'A1WS9UHL45VZ0X', 'A3C8JI69WPTKWH', 'A3C2X1L5PVNNLV',
#        'A3U7EIF0P9GQKI', 'A1JZOOVYE1K4R3', 'A2196WCNDZULFS',
#        'A10JXOU89D5RXR', 'A3KIC0UFTOB0MY', 'A2YGOORS5N9RW8',
#        'A2A4Q3XU50SBE2', 'A23FMTVKQEYCMW', 'A2KOVSTZGWSVYC',
#        'A3VLJA3CELO9EZ', 'A2BYSC5EQAIV8D', 'AA4QUDJHEUKYX',
#        'AXAO7UJYYEFCO', 'A1RFS3YXD1ZIKG', nan, 'asdfasdfasdfasd',
#        'asdfasdfasdfacc', 'asdfghjklqwe', 'testsubject001',
#        'testsubject003', 'testsubject002', 'camerontesting1',
#        'will000testing1'], dtype=object)

# %%
df_cw = df_full[(df_full['iterationName'] == iterationName)][df_full['workerId'].isin(['camerontesting1','will000testing1'])]
# Out:
# /Users/will/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_cw.eventType.unique()
# Out:
# array(['chatMessage', 'block', 'endTrial', 'exitSurvey'], dtype=object)

# %%
df_cw[df_cw.eventType=='block']
# Out:
#                            _id iterationName  \
# 6115  5f4406b1c5668f67e677fba7    pre-pilot3
# 6116  5f4406b4c5668f67e677fba8    pre-pilot3
# 6119  5f4406c2c5668f67e677fbab    pre-pilot3
# 6120  5f4406c3c5668f67e677fbac    pre-pilot3
# 6121  5f4406c4c5668f67e677fbad    pre-pilot3
# ...                        ...           ...
# 6236  5f440811c5668f67e677fc20    pre-pilot3
# 6237  5f440812c5668f67e677fc21    pre-pilot3
# 6238  5f440813c5668f67e677fc22    pre-pilot3
# 6239  5f440815c5668f67e677fc23    pre-pilot3
# 6240  5f44081ac5668f67e677fc24    pre-pilot3
#
#                                          gameid          time  \
# 6115  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6116  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6119  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6120  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6121  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# ...                                         ...           ...
# 6236  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6237  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6238  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6239  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
# 6240  0249-5e989b45-8e74-4f49-ba9a-aa0b971f485c  1.598294e+12
#
#              workerId assignmentId  leftTarget rightTarget  trialNum  turnNum  \
# 6115  will000testing1    undefined  horizontal    vertical  practice      1.0
# 6116  will000testing1    undefined  horizontal    vertical  practice      1.0
# 6119  will000testing1    undefined           C          Pi         0      1.0
# 6120  will000testing1    undefined           C          Pi         0      1.0
# 6121  will000testing1    undefined           C          Pi         0      1.0
# ...               ...          ...         ...         ...       ...      ...
# 6236  will000testing1    undefined          Pi           L        11      1.0
# 6237  will000testing1    undefined          Pi           L        11      1.0
# 6238  will000testing1    undefined          Pi           L        11      1.0
# 6239  will000testing1    undefined          Pi           L        11      1.0
# 6240  will000testing1    undefined          Pi           L        11      1.0
#
#       ... confused comments strategy role totalLength  cumulativeScore  \
# 6115  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6116  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6119  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6120  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6121  ...      NaN      NaN      NaN  NaN         NaN              NaN
# ...   ...      ...      ...      ...  ...         ...              ...
# 6236  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6237  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6238  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6239  ...      NaN      NaN      NaN  NaN         NaN              NaN
# 6240  ...      NaN      NaN      NaN  NaN         NaN              NaN
#
#       cumulativeBonus  trialScore  workerID individualPracticeAttempts
# 6115              NaN         NaN       NaN                          1
# 6116              NaN         NaN       NaN                          1
# 6119              NaN         NaN       NaN                          1
# 6120              NaN         NaN       NaN                          1
# 6121              NaN         NaN       NaN                          1
# ...               ...         ...       ...                        ...
# 6236              NaN         NaN       NaN                          1
# 6237              NaN         NaN       NaN                          1
# 6238              NaN         NaN       NaN                          1
# 6239              NaN         NaN       NaN                          1
# 6240              NaN         NaN       NaN                          1
#
# [98 rows x 39 columns]

# %% [markdown]
# ## Trial Level Data

# %% [markdown]
# ## Create DF for each event

# %%
#read in dataframes from each eventType
df_block = pd.read_csv('../results/csv/compabs_block_{}.csv'.format(iterationName))
df_chat = pd.read_csv('../results/csv/compabs_chat_{}.csv'.format(iterationName))
df_exit = pd.read_csv('../results/csv/compabs_exit_{}.csv'.format(iterationName))
df_trial = pd.read_csv('../results/csv/compabs_trial_{}.csv'.format(iterationName))

# %%
#manually build full df (needs to be generalized)
#
df_block0 = pd.read_csv('../results/csv/compabs_block_{}.csv'.format('livetest0'))
df_chat0 = pd.read_csv('../results/csv/compabs_chat_{}.csv'.format('livetest0'))
df_exit0 = pd.read_csv('../results/csv/compabs_exit_{}.csv'.format('livetest0'))
df_trial0 = pd.read_csv('../results/csv/compabs_trial_{}.csv'.format('livetest0'))
#
df_block1 = pd.read_csv('../results/csv/compabs_block_{}.csv'.format('pilot0'))
df_chat1 = pd.read_csv('../results/csv/compabs_chat_{}.csv'.format('pilot0'))
df_exit1 = pd.read_csv('../results/csv/compabs_exit_{}.csv'.format('pilot0'))
df_trial1 = pd.read_csv('../results/csv/compabs_trial_{}.csv'.format('pilot0'))
#
df_block2 = pd.read_csv('../results/csv/compabs_block_{}.csv'.format('pilot2'))
df_chat2 = pd.read_csv('../results/csv/compabs_chat_{}.csv'.format('pilot2'))
df_exit2 = pd.read_csv('../results/csv/compabs_exit_{}.csv'.format('pilot2'))
df_trial2 = pd.read_csv('../results/csv/compabs_trial_{}.csv'.format('pilot2'))

df_block = pd.concat([df_block0,df_block1,df_block2])
df_chat = pd.concat([df_chat0,df_chat1,df_chat2])
df_exit = pd.concat([df_exit0,df_exit1,df_exit2])
df_trial = pd.concat([df_trial0,df_trial1,df_trial2])

print("Total Completed Games:",len(df_exit.gameid.unique()))
# Out:
# Total Completed Games: 21

# %% [markdown]
# #### Write to data frames

# %%
df_block.to_csv('df_block.csv', header=True, index=False) 
df_chat.to_csv('df_chat.csv', header=True, index=False) 
df_exit.to_csv('df_exit.csv', header=True, index=False) 
df_trial.to_csv('df_trial.csv', header=True, index=False)

# %% [markdown]
# #### Exclusion Criteria

# %%
#How many dyads fulfill 75% Accuracy on 75% of trials
df75 = pd.DataFrame(df_trial.groupby(['gameid', 'trialNum'])['trialScore'].sum()>75).groupby(['gameid']).sum()
df75['trials'] = df75['trialScore']
print("Total dyads achieving 75% Accuracy on 75% of trials:",len(df75[df75['trials']>=9]))
# Out:
# Total dyads achieving 75% Accuracy on 75% of trials: 13

# %%
#df_exit2 = pd.read_csv('../results/csv/compabs_exit_pilot2.csv')
df_exit.confused
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-abe2955e414e> in <module>
#       1 #df_exit2 = pd.read_csv('../results/csv/compabs_exit_pilot2.csv')
# ----> 2 df_trial.confused
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'confused'

# %% [markdown]
# #### Total Game Duration (for Gameplay)

# %%
(df_exit.groupby(['gameid'])['totalLength'].max()/60000).hist()
plt.xlabel("Duration (min)")
plt.show()

# %%
#average completion time
(df_exit.groupby(['gameid'])['totalLength'].max()/60000).mean()
# Out:
# 35.44269333333333

# %% [markdown]
# ### Inspect some raw data: language

# %%
#create columns for char and word counts
df_chat['word_count'] = df_chat['content'].str.split(' ').str.len()
df_chat['char_count'] = df_chat['content'].str.len()

# %%
#Coerce trialNum to numeric -- will remove "practice". Thoughts?
df_chat['trialNum'] = pd.to_numeric(df_chat['trialNum'], errors = 'coerce')

# %%
#inspect specific chat history of one dyad
dyadGameId = '8548-343a533f-0369-4b20-bbd4-a00f25359cea'
df_chat[(df_chat.gameid == dyadGameId)]['content'].unique()
# Out:
# array(['move left', 'move right\n', 'build the block\n',
#        'build the red block\n', 'move the right block to the left',
#        'move the lift block to the right\n', 'move the right red',
#        'build the blue block', 'bulid the red block',
#        'move the right bulid the left', 'move the blue block',
#        'move the left block to the right corner',
#        'build the block to next blue block',
#        'move the red block to the right corner to the blue block',
#        'move to left block to right', 'move the next block', 'move right',
#        'bulid the right the left block\n', 'move left\n',
#        'bulid the right to left block', 'move left to right block',
#        'move right to left block ', 'mobe left', 'movbe left'],
#       dtype=object)

# %% [markdown]
# ### Inspect some raw data: display block towers

# %%
importlib.reload(drawing)
df_block['w'] = df_block['width']
df_block['h'] = df_block['height']
floatCols = ['w','h','blockNum','turnNum','x','y']
df_block[floatCols] = df_block[floatCols].applymap(np.int64)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
drawing.draw_from_actions_subplot(df_block[(df_block.leftTarget == 'C') & 
                                           (df_block.rightTarget == 'Pi') &
                                           (df_block.gameid == '0662-7a9212c9-5aa7-44de-9ed7-4663c56562d2')], 
                                  ax, 
                                  world_size = [12,8])
plt.title("Block Heat Map for 'C, Pi'")
plt.show()

# %% [markdown]
# ## Make basic visualizations and calculate descriptives

# %% [markdown]
# ### Architect: mean number of words across trials

# %%
#Get sum of words for each trial, group by game then average across games
print(df_chat.groupby(['gameid','trialNum'])['word_count'].sum().groupby(['trialNum']).mean())
# Out:
# trialNum
# 0.0     55.35
# 1.0     49.50
# 2.0     38.95
# 3.0     33.90
# 4.0     33.00
# 5.0     28.20
# 6.0     23.25
# 7.0     21.60
# 8.0     19.15
# 9.0     17.95
# 10.0    17.90
# 11.0    17.95
# Name: word_count, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','trialNum'])['word_count'].sum().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Word Count')
# Out:
# Text(0, 0.5, 'Word Count')

# %%
fig, ax = plt.subplots(figsize=(15,7))
mean = df_chat.groupby(['gameid','trialNum'])['word_count'].sum().groupby(['trialNum']).mean()
std = df_chat.groupby(['gameid','trialNum'])['word_count'].sum().groupby(['trialNum']).std()

plt.errorbar(mean.index, mean, yerr=2*std, linestyle='--')
plt.ylabel('Word Count')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','repNum'])['word_count'].sum().groupby(['repNum']).mean().plot(ax = ax)
plt.ylabel('Word Count')
# Out:
# Text(0, 0.5, 'Word Count')

# %% [markdown]
# ###  Architect: mean number of characters across trials

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','trialNum'])['char_count'].sum().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Char Count')
# Out:
# Text(0, 0.5, 'Char Count')

# %% [markdown]
# ### Architect: mean number of messages (across turns within a trial) across trials

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','trialNum'])['_id'].count().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Messages per trial')
# Out:
# Text(0, 0.5, 'Messages per trial')

# %% [markdown]
# ### Architect: Total typing time (across turns within at trial) across trials

# %%
#check time elapsed
df_chat["timeElapsedInTurn"] = pd.to_numeric(df_chat['timeElapsedInTurn'])

# %%
## line plots
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','trialNum'])['timeElapsedInTurn'].sum().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Average Time elapsed, Architect')
# Out:
# Text(0, 0.5, 'Average Time elapsed, Architect')

# %%
df_chat.groupby(['gameid','trialNum'])['timeElapsedInTurn'].sum().groupby(['trialNum']).mean()
# Out:
# trialNum
# 0.0     152317.30
# 1.0     129113.90
# 2.0      91571.75
# 3.0      77040.30
# 4.0      76259.70
# 5.0      60563.00
# 6.0      47003.85
# 7.0      44389.60
# 8.0      37205.60
# 9.0      33323.25
# 10.0     29886.65
# 11.0     33289.20
# Name: timeElapsedInTurn, dtype: float64

# %% [markdown]
# ### Builder: Reconstruction accuracy (intersection over union, IOU) across trials

# %%
#Coerce trialNum to numeric -- will remove "practice". Thoughts?
df_trial['trialNum'] = pd.to_numeric(df_trial['trialNum'], errors = 'coerce')
#Coerce trialNum to numeric -- will remove "practice". Thoughts?
df_block['trialNum'] = pd.to_numeric(df_block['trialNum'], errors = 'coerce')

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_trial.groupby(['trialNum','gameid'])['trialScore'].sum().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Trial Score')
# Out:
# Text(0, 0.5, 'Trial Score')

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_trial.groupby(['gameid','repNum'])['trialScore'].mean().groupby(['repNum']).mean().plot(ax = ax)
plt.ylabel('Trial Score')
# Out:
# Text(0, 0.5, 'Trial Score')

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_trial.groupby(['trialNum','gameid'])['trialScore'].sum().unstack().plot(ax = ax)
ax.get_legend().remove()
plt.ylabel('Trial Score')
# Out:
# Text(0, 0.5, 'Trial Score')

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_trial.groupby(['repNum','gameid'])['trialScore'].mean().unstack().plot(ax = ax)
ax.get_legend().remove()
plt.ylabel('Trial Score')
# Out:
# Text(0, 0.5, 'Trial Score')

# %%
df_trial.groupby(['gameid'])['trialScore'].mean().hist()

# %%
#Dist of trial scores:
(df_trial.groupby(['gameid','trialNum']).trialScore.max().hist(bins = 8))
plt.show()

# %%
pd.options.display.max_rows = 4000
df_trial.groupby(['gameid','trialNum']).trialScore.max()
# Out:
# gameid                                     trialNum
# 0662-7a9212c9-5aa7-44de-9ed7-4663c56562d2  0.0         100.0
#                                            1.0         100.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 1494-029e2297-bd3f-4cfe-be00-d06d36724e4e  0.0          87.0
#                                            1.0         100.0
#                                            2.0          87.0
#                                            3.0          31.0
#                                            4.0          68.0
#                                            5.0          31.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 1959-2f467add-c0d9-49a6-b35c-c5a40cca728d  0.0          43.0
#                                            1.0          37.0
#                                            2.0          12.0
#                                            3.0          18.0
#                                            4.0           6.0
#                                            5.0           6.0
#                                            6.0          18.0
#                                            7.0          31.0
#                                            8.0          37.0
#                                            9.0          37.0
#                                            10.0         37.0
#                                            11.0         31.0
# 2083-6615b44d-57a8-4953-beca-afa15df0c195  0.0          87.0
#                                            1.0         100.0
#                                            2.0          93.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0          87.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0          31.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0         68.0
# 2391-2f396ec8-517f-4681-b366-51f930bcac22  0.0          68.0
#                                            1.0          68.0
#                                            2.0          93.0
#                                            3.0         100.0
#                                            4.0          75.0
#                                            5.0          87.0
#                                            6.0         100.0
#                                            7.0          87.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 2461-b9a83dc7-d6fc-4939-a889-9d4739a87dc6  0.0          81.0
#                                            1.0          81.0
#                                            2.0          68.0
#                                            3.0          50.0
#                                            4.0          37.0
#                                            5.0          62.0
#                                            6.0          43.0
#                                            7.0          31.0
#                                            8.0          31.0
#                                            9.0          12.0
#                                            10.0         25.0
#                                            11.0         43.0
# 3086-e9f8b532-4969-4703-852e-f6f029d281e2  0.0          81.0
#                                            1.0          68.0
#                                            2.0          75.0
#                                            3.0         100.0
#                                            4.0          81.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0          75.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0         87.0
# 3224-ea79f879-98a3-43a8-8976-f941c8b8790d  0.0          93.0
#                                            1.0         100.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 3300-92747c2e-ca2a-48cd-996a-54fde9f489be  0.0         100.0
#                                            1.0          93.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 3878-afb0aafe-768b-485b-9e69-251a58fcf3ff  0.0         100.0
#                                            1.0         100.0
#                                            2.0          93.0
#                                            3.0          93.0
#                                            4.0          87.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 4282-2568ede7-963d-4fee-ab15-b69e472ef360  0.0          56.0
#                                            1.0          87.0
#                                            2.0          43.0
#                                            3.0          93.0
#                                            4.0          81.0
#                                            5.0          68.0
#                                            6.0          75.0
#                                            7.0          62.0
#                                            8.0          81.0
#                                            9.0          56.0
#                                            10.0         68.0
#                                            11.0         87.0
# 4909-705b801e-4ec3-4910-b180-bb7612d80f25  0.0         100.0
#                                            1.0          93.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 5584-cb7536bf-73d0-4d3c-a0ec-2735882de660  0.0          37.0
#                                            1.0          37.0
#                                            2.0          37.0
#                                            3.0          50.0
#                                            4.0          12.0
#                                            5.0          12.0
#                                            6.0          31.0
#                                            7.0          25.0
#                                            8.0          25.0
#                                            9.0          31.0
#                                            10.0         37.0
#                                            11.0         56.0
# 5895-de8412be-4cb1-49e4-9c61-ca6a11481af8  0.0          75.0
#                                            1.0          50.0
#                                            2.0          81.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 6691-dee56275-2f4b-44b8-a47c-d4d41c945670  0.0          31.0
#                                            1.0          37.0
#                                            2.0          43.0
#                                            3.0          18.0
#                                            4.0          43.0
#                                            5.0          31.0
#                                            6.0          12.0
#                                            7.0          43.0
#                                            8.0          25.0
#                                            9.0          37.0
#                                            10.0         31.0
#                                            11.0         31.0
# 6753-24a4a6e7-e017-4cba-a068-8dea7af05cf2  0.0          62.0
#                                            1.0         100.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 7109-2ef42705-61df-4552-a6ce-e9e6966dd760  0.0          68.0
#                                            1.0          81.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0         100.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0         100.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 8548-343a533f-0369-4b20-bbd4-a00f25359cea  0.0          37.0
#                                            1.0          25.0
#                                            2.0          12.0
#                                            3.0          37.0
#                                            4.0          12.0
#                                            5.0          18.0
#                                            6.0          12.0
#                                            7.0          25.0
#                                            8.0          25.0
#                                            9.0          18.0
#                                            10.0         31.0
#                                            11.0         12.0
# 9387-db1af5ad-b089-48ad-a730-baee40f08177  0.0          68.0
#                                            1.0         100.0
#                                            2.0         100.0
#                                            3.0         100.0
#                                            4.0          87.0
#                                            5.0         100.0
#                                            6.0         100.0
#                                            7.0          93.0
#                                            8.0         100.0
#                                            9.0         100.0
#                                            10.0        100.0
#                                            11.0        100.0
# 9940-419571e8-f021-4083-9210-892897d2b4df  0.0          62.0
#                                            1.0          87.0
#                                            2.0          81.0
#                                            3.0         100.0
#                                            4.0          75.0
#                                            5.0          93.0
#                                            6.0         100.0
#                                            7.0          43.0
#                                            8.0          31.0
#                                            9.0          37.0
#                                            10.0         37.0
#                                            11.0         43.0
# Name: trialScore, dtype: float64

# %% [markdown]
# ### Architect: Distribution of words over trials

# %% [markdown]
# ### Builder: Distribution of blocks placed per utterance

# %%
(df_block.groupby(['gameid','trialNum', 'turnNum'])['_id'].count()).hist(bins = 8)
plt.show()

# %% [markdown]
# ### Builder: Total reconstruction time (summed build time across turns, within each trial) across trials

# %%
#check time elapsed
df_block["timeElapsedInTurn"] = pd.to_numeric(df_block['timeElapsedInTurn'])

# %%
df_block.groupby(['gameid','trialNum'])['timeElapsedInTurn'].sum()
# Out:
# gameid                                     trialNum
# 0662-7a9212c9-5aa7-44de-9ed7-4663c56562d2  0.0         124294.0
#                                            1.0         127660.0
#                                            2.0         296930.0
#                                            3.0         178785.0
#                                            4.0         198308.0
#                                            5.0         285694.0
#                                            6.0          87753.0
#                                            7.0          92469.0
#                                            8.0         106286.0
#                                            9.0          80902.0
#                                            10.0         95916.0
#                                            11.0         85878.0
# 1494-029e2297-bd3f-4cfe-be00-d06d36724e4e  0.0         106131.0
#                                            1.0          84608.0
#                                            2.0         148591.0
#                                            3.0         183137.0
#                                            4.0         230111.0
#                                            5.0         160650.0
#                                            6.0         171688.0
#                                            7.0         101140.0
#                                            8.0         100676.0
#                                            9.0          77430.0
#                                            10.0        109506.0
#                                            11.0         85205.0
# 1959-2f467add-c0d9-49a6-b35c-c5a40cca728d  0.0          98256.0
#                                            1.0          60477.0
#                                            2.0         181491.0
#                                            3.0         132748.0
#                                            4.0         134709.0
#                                            5.0          88030.0
#                                            6.0         145547.0
#                                            7.0         105413.0
#                                            8.0          71471.0
#                                            9.0         194056.0
#                                            10.0         81042.0
#                                            11.0        171274.0
# 2083-6615b44d-57a8-4953-beca-afa15df0c195  0.0        -150089.0
#                                            1.0        -143036.0
#                                            2.0        -152033.0
#                                            3.0        -178652.0
#                                            4.0        -189278.0
#                                            5.0        -195494.0
#                                            6.0        -186174.0
#                                            7.0        -185868.0
#                                            8.0        -130442.0
#                                            9.0        -170108.0
#                                            10.0       -177005.0
#                                            11.0        -81189.0
# 2391-2f396ec8-517f-4681-b366-51f930bcac22  0.0         163229.0
#                                            1.0         102423.0
#                                            2.0          83749.0
#                                            3.0          53189.0
#                                            4.0          51403.0
#                                            5.0          71806.0
#                                            6.0          87904.0
#                                            7.0          72952.0
#                                            8.0          48040.0
#                                            9.0          67837.0
#                                            10.0         37230.0
#                                            11.0         28967.0
# 2461-b9a83dc7-d6fc-4939-a889-9d4739a87dc6  0.0          80223.0
#                                            1.0          64516.0
#                                            2.0          61877.0
#                                            3.0          73225.0
#                                            4.0         132506.0
#                                            5.0         110942.0
#                                            6.0         123743.0
#                                            7.0          58646.0
#                                            8.0          56893.0
#                                            9.0          75669.0
#                                            10.0        111377.0
#                                            11.0         43965.0
# 3086-e9f8b532-4969-4703-852e-f6f029d281e2  0.0         126252.0
#                                            1.0         106318.0
#                                            2.0         117428.0
#                                            3.0          88345.0
#                                            4.0          93381.0
#                                            5.0         107955.0
#                                            6.0         102990.0
#                                            7.0          97788.0
#                                            8.0         101273.0
#                                            9.0          89855.0
#                                            10.0        109310.0
#                                            11.0        110223.0
# 3224-ea79f879-98a3-43a8-8976-f941c8b8790d  0.0          89487.0
#                                            1.0          78863.0
#                                            2.0         101802.0
#                                            3.0          95245.0
#                                            4.0          93959.0
#                                            5.0         143636.0
#                                            6.0         132503.0
#                                            7.0         143006.0
#                                            8.0         102018.0
#                                            9.0         109665.0
#                                            10.0        110108.0
#                                            11.0        121099.0
# 3300-92747c2e-ca2a-48cd-996a-54fde9f489be  0.0         172319.0
#                                            1.0         111569.0
#                                            2.0         148003.0
#                                            3.0         139163.0
#                                            4.0         115945.0
#                                            5.0         116858.0
#                                            6.0         106024.0
#                                            7.0         131287.0
#                                            8.0         130050.0
#                                            9.0         109517.0
#                                            10.0        144689.0
#                                            11.0        146629.0
# 3878-afb0aafe-768b-485b-9e69-251a58fcf3ff  0.0          88405.0
#                                            1.0          77307.0
#                                            2.0          75562.0
#                                            3.0          79329.0
#                                            4.0          77684.0
#                                            5.0          48036.0
#                                            6.0          53388.0
#                                            7.0          50663.0
#                                            8.0          42501.0
#                                            9.0          35490.0
#                                            10.0         42911.0
#                                            11.0         30848.0
# 4282-2568ede7-963d-4fee-ab15-b69e472ef360  0.0         332041.0
#                                            1.0         187610.0
#                                            2.0         121802.0
#                                            3.0         133218.0
#                                            4.0         154404.0
#                                            5.0         152426.0
#                                            6.0         115407.0
#                                            7.0         167912.0
#                                            8.0          91359.0
#                                            9.0         198499.0
#                                            10.0        179507.0
#                                            11.0        129677.0
# 4909-705b801e-4ec3-4910-b180-bb7612d80f25  0.0          69802.0
#                                            1.0          65952.0
#                                            2.0          55918.0
#                                            3.0          48327.0
#                                            4.0          42758.0
#                                            5.0          41783.0
#                                            6.0          46444.0
#                                            7.0          54827.0
#                                            8.0          53551.0
#                                            9.0          43585.0
#                                            10.0         47877.0
#                                            11.0         46977.0
# 5584-cb7536bf-73d0-4d3c-a0ec-2735882de660  0.0         211318.0
#                                            1.0         136352.0
#                                            2.0         103800.0
#                                            3.0          84065.0
#                                            4.0         143266.0
#                                            5.0         346588.0
#                                            6.0          65928.0
#                                            7.0         150277.0
#                                            8.0          69592.0
#                                            9.0          65370.0
#                                            10.0        107839.0
#                                            11.0         80295.0
# 5895-de8412be-4cb1-49e4-9c61-ca6a11481af8  0.0         200057.0
#                                            1.0         151409.0
#                                            2.0         199450.0
#                                            3.0         241400.0
#                                            4.0         197837.0
#                                            5.0          91004.0
#                                            6.0         125543.0
#                                            7.0         106768.0
#                                            8.0          90720.0
#                                            9.0          94984.0
#                                            10.0        131873.0
#                                            11.0        118222.0
# 6691-dee56275-2f4b-44b8-a47c-d4d41c945670  0.0         124769.0
#                                            1.0         126178.0
#                                            2.0         127321.0
#                                            3.0         129952.0
#                                            4.0         113332.0
#                                            5.0         160809.0
#                                            6.0         111669.0
#                                            7.0          82867.0
#                                            8.0          94153.0
#                                            9.0          62312.0
#                                            10.0         79332.0
#                                            11.0         69165.0
# 6753-24a4a6e7-e017-4cba-a068-8dea7af05cf2  0.0          86394.0
#                                            1.0          60730.0
#                                            2.0          66691.0
#                                            3.0         111125.0
#                                            4.0         128720.0
#                                            5.0          71499.0
#                                            6.0         147566.0
#                                            7.0          79653.0
#                                            8.0          77820.0
#                                            9.0          52551.0
#                                            10.0        167340.0
#                                            11.0         75856.0
# 7109-2ef42705-61df-4552-a6ce-e9e6966dd760  0.0         124138.0
#                                            1.0         154621.0
#                                            2.0         197392.0
#                                            3.0         108018.0
#                                            4.0         195088.0
#                                            5.0         148753.0
#                                            6.0          88106.0
#                                            7.0         144310.0
#                                            8.0         133162.0
#                                            9.0         125587.0
#                                            10.0        132699.0
#                                            11.0        123693.0
# 8548-343a533f-0369-4b20-bbd4-a00f25359cea  0.0         124537.0
#                                            1.0         247400.0
#                                            2.0         196945.0
#                                            3.0         205860.0
#                                            4.0         235862.0
#                                            5.0         147332.0
#                                            6.0         124342.0
#                                            7.0         152055.0
#                                            8.0          99186.0
#                                            9.0         132359.0
#                                            10.0        119806.0
#                                            11.0         91522.0
# 9387-db1af5ad-b089-48ad-a730-baee40f08177  0.0         205120.0
#                                            1.0         317300.0
#                                            2.0         226822.0
#                                            3.0         145127.0
#                                            4.0         394297.0
#                                            5.0         190858.0
#                                            6.0         125215.0
#                                            7.0         192470.0
#                                            8.0         148768.0
#                                            9.0         136153.0
#                                            10.0        138547.0
#                                            11.0        100666.0
# 9940-419571e8-f021-4083-9210-892897d2b4df  0.0         149182.0
#                                            1.0          96865.0
#                                            2.0         167564.0
#                                            3.0         110541.0
#                                            4.0          82158.0
#                                            5.0         111667.0
#                                            6.0          96770.0
#                                            7.0         164151.0
#                                            8.0         117811.0
#                                            9.0         215789.0
#                                            10.0        239451.0
#                                            11.0        246619.0
# Name: timeElapsedInTurn, dtype: float64

# %%
## line plots
fig, ax = plt.subplots(figsize=(15,7))
df_block.groupby(['gameid','trialNum'])['timeElapsedInTurn'].sum().groupby(['trialNum']).mean().plot(ax = ax)
plt.ylabel('Average Time elapsed, Builder')
# Out:
# Text(0, 0.5, 'Average Time elapsed, Builder')

# %%
## line plots: time for each builder
fig, ax = plt.subplots(figsize=(15,7))
df_block.groupby(['trialNum','gameid'])['timeElapsedInTurn'].sum().unstack().plot(ax = ax)
ax.get_legend().remove()
plt.ylabel('Time elapsed in trial Builder')
# Out:
# Text(0, 0.5, 'Time elapsed in trial Builder')

# %%
df_block.timeElapsedInTurn.min()
# Out:
# -28382.0

# %% [markdown]
# ### Now, let's look at the DVs above, w.r.t. repetition of scenes, IGNORING which side a tower appears on... so across four repetitions (where [A,B] is equivalent to [B,A])
#
# #### use rep num
#
# TBD. We've done this in the R notebook though....

# %%
#
def convert(list): 
    return tuple(i for i in list)
df_chat['targetSet'] = convert(df_chat[['leftTarget', 'rightTarget']].values.tolist())

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_chat.groupby(['gameid','targetSet'])['word_count'].sum().groupby(['targetSet']).mean().plot.bar(ax = ax)
plt.ylabel('Words Per figure')
# Out:
# Text(0, 0.5, 'Words Per figure')
