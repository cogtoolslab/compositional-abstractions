# %% [markdown]
# # Upload tower stimuli to s3

# %%
#Which experiment? bucket_name is the name of the experiment and will be name of the databases both on mongoDB and S3

# 4 block towers
# bucket_name = 'lax-tower-4-block-unique-silhouettes-json' #containment
# stim_version = 'tower_4_block_unique_silhouettes_json'


# composites (includes ambiguous stims twice)
bucket_name = 'lax-tower-4-block-unique-silhouettes-composites-json' #containment
stim_version = 'tower_4_block_unique_silhouettes_composites_json'

# %%
import os
from glob import glob
import boto3
import botocore
from IPython.display import clear_output
import json
import pandas as pd
from PIL import Image

# %%
def list_files(paths, ext='json'):
    """Pass list of folders if there are stimuli in multiple folders. 
    Make sure that the containing folder is informative, as the rest of the path is ignored in naming. 
    Also returns filenames as uploaded to S3"""
    if type(paths) is not list:
        paths = [paths]
    results = []
    names = []
    for path in paths:
        results += [y for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
        names += [os.path.split(y)[1] for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
    return results,names

# %%
## helper to speed things up by not uploading images if they already exist, can be overriden 
def check_exists(s3, bucket_name, stim_name):
    try:
        s3.Object(bucket_name,stim_name).load()    
        return True
    except botocore.exceptions.ClientError as e:    
        if (e.response['Error']['Code'] == "404"):
            print('The object does not exist.')
            return False
        else:
            print('Something else has gone wrong with {}'.format(stim_name))

# %% [markdown]
# Pass list of folders if there are stimuli in multiple folders. Make sure that the containing folder is informative, as the rest of the path is ignored in naming.

# %%
## set up paths, etc.
# paths_to_stim = ['./example'] ## provide a list of full paths here.
paths_to_stim = [
    
    # tower silhouettes
    "./" + stim_version,
    
]

# paths_to_stim = glob.glob()
full_stim_paths, filenames = [x for x in list_files(paths_to_stim) if x !='.DS_Store'] #generate filenames and stimpaths
print('We have {} stimuli to upload.'.format(len(full_stim_paths)))
# Out:
# We have 514 stimuli to upload.

# %% [markdown]
# Upload to S3. This expects the `.aws/credentials` file in your home directory.

# %%
reallyRun = True
if reallyRun:

    ## establish connection to s3 
    s3 = boto3.resource('s3')

    ## create a bucket with the appropriate bucket name
    try: 
        b = s3.create_bucket(Bucket=bucket_name) 
        print('Created new bucket.')
#     except NoCredentialsError:
#         print("Credential missing") #.aws/credentials should be in home folder, not in repo folder
    except:
        b = s3.Bucket(bucket_name)
        print('Bucket already exists.')

    ## do we want to overwrite files on s3?
    overwrite = True
    
    ## set bucket and objects to public
    b.Acl().put(ACL='public-read') ## sets bucket to public

    ## now let's loop through stim paths and actually upload to s3 (woot!)
    for i,path_to_file in enumerate(full_stim_paths):        # use sorted(full_stim_paths) when not using photodraw32
        stim_name = filenames[i]
        if ((check_exists(s3, bucket_name, stim_name)==False) | (overwrite==True)):
            print('Now uploading {} as {} | {} of {}'.format(os.path.split(path_to_file)[-1],stim_name,(i+1),len(full_stim_paths)))
            s3.Object(bucket_name,stim_name).put(Body=open(path_to_file,'rb')) ## upload stimuli
            s3.Object(bucket_name,stim_name).Acl().put(ACL='public-read') ## set access controls
        else: 
            print('Skipping {} | {} of {} because it already exists.'.format(os.path.split(path_to_file)[-1],(i+1),len(full_stim_paths)))
        clear_output(wait=True)
print('Done!')
# Out:
# Done!

# %%
for my_bucket_object in b.objects.all():
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_092_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_097_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_100_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_101_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_102_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_109_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_111_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_114_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_115_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_116_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_118_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_121_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_122_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_125_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_126_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_127_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_102.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_109.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_111.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_114.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_115.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_116.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_118.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_121.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_122.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_125.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_126.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_127.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_128.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_128_129.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_129_092.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_129_097.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_129_100.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_129_101.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_talls_129_102.json')
# ...
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_018_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_018_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_018_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_018_022.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_018_024.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_019_025.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_020_025.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_002.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_010.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_012.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_022.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_024.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_022_025.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_002.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_010.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_012.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_022.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_024.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_023_025.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_002.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_010.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_012.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_022.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_024.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_024_025.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_001.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_002.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_005.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_006.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_008.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_010.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_011.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_012.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_013.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_014.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_015.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_018.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_019.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_020.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_022.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_023.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_024.json')
# s3.ObjectSummary(bucket_name='lax-tower-4-block-unique-silhouettes-composites-json', key='tower_4_block_unique_silhouettes_composite_wides_025_025.json')

# %%
### add burn-in trials

# %%
### add catch trials
